# %%
# import statements
import json
import os
import time

# %%
# Define the keywords that will be used to extract the imperative sentences
# Rules are identified from the paper - https://www.aclweb.org/anthology/W14-2117.pdf
# 1. "find those sentences with a verb (in its base form) as the root 
#     in the phrase structure and this particular verb has no 
#.    subject child in the dependency structure" 
#.    Example: You must first discuss the matter there, and you need to be specific”
# 2. "recognize the use of a personal pronoun or noun (e.g., “you”, “we”,
#.     or a username) followed by a modal verb (e.g., “should”, “must”, “need”) as an imperative"


# Source: https://www.myenglishpages.com/site_php_files/grammar-lesson-modals.php
modal_verbs = ['can', 'could', 'may', 'might', 'will', 'would', 'shall','should', 'must', 'ought', 'dare', 'had better', 'ask']
modal_verbs = ['can', 'may', 'might', 'will', 'would', 'shall','should', 'must', 'ought', 'dare', 'had better', 'ask']

# Source: https://grammar.yourdictionary.com/parts-of-speech/pronouns/list-of-personal-pronouns.html
# personal_pronoun = ['I', 'me', 'we', 'us', 'you', 'he', 'she', 'her', 'him', 'it', 'they', 'them']
personal_pronoun = ['us', 'you', 'he', 'she', 'her', 'him', 'it', 'they', 'them']

# %%
# Check for rule 2

# Create combinations of possibilities for a sentence to be imperative
combinations = []
# form combinations of words and put them as a list
for pronoun in personal_pronoun:
    for verb in modal_verbs:
        combinations.append(pronoun + ' ' + verb)
        
print('Number of combinations for rule 2 =', len(combinations))
# Out:
# Number of combinations for rule 2 = 108

# %%
# Using rule 2 to check imperative snetences
def check_imperative_r2(combinations, sentence):
    if any(combo in sentence.lower() for combo in combinations):
        return True
    return False

# %%
IP_DIR = '../data/input/'
OP_DIR = '../data/output/'

# %% [markdown]
# ## Quora Dataset

# %%
# Read Quora Question Answer Dataset
def get_quora_sentences(ip_path):
    
    sentences = []

    with open(ip_path) as fp:
        data = json.load(fp)

        for qa_pair in data.items():
            q_id, answer = qa_pair
            
            for sent in answer['sentences']:
                # print(sent)
                split_sentences = list(sent.split('.'))
                for x in split_sentences:
                    if len(x) > 1:
                        sentences.append(x)
            '''
            # This part is one of the sentences from answer['sentences']
            split_sentences = list(sent.split('.'))
            for x in split_sentences:
                if len(x) > 1:
                    print('\t', x)
                    sentences.append(x)
            '''
                
    print('Number of sentences =', len(sentences))
    return sentences

# %%
sentences_q = []
dataset = 'Quora_QAD'

fname = 'Q2AD_v1_test.json'
ip_path = os.path.join(IP_DIR, dataset, fname)
sentences_q.extend(get_quora_sentences(ip_path))

fname = 'Q2AD_v1_train.json'
ip_path = os.path.join(IP_DIR, dataset, fname)
sentences_q.extend(get_quora_sentences(ip_path))

print('Total sentences available: ', len(sentences_q))
# Out:
# Number of sentences = 109
# Number of sentences = 457
# Total sentences available:  566

# %%
sentences_q
# Out:
# ["It's a matter of economy of scale",
#  'So in a buffet situation, you can buy larger quantities from vendors and save a huge amount',
#  'The trend now is that beauty is all about the look',
#  'The eye lashes, lip sticks, foundations and face cakes',
#  "Because it's also the end of all joy and happiness and social interaction",
#  "We don't fear death so much as we fear having to give up everything we know and love",
#  'Table tennis is tremendously fun, and a much better source of exercise than people tend to give it credit for',
#  'She doesn’t need to throw out useful things for no reason',
#  'She received these things as gifts, they are still (presumably) functional and useful, why would she get rid of them?',
#  'I get cultural and religious shocks once in a while',
#  'Here on Quora, there are bold people who write explicitly and even if I appreciate the meat therein, I feel restrained to vote them up',
#  'Mr',
#  ' Mohandas Karam Chand Gandhi - Bapuji was a barrister by profession',
#  'There are many students who crack IIT JEE without coaching',
#  'If you go through the profiles and lives of JEE Advanced toppers of last few year, you will find half or them or more cracking IIT JEE without having any coaching',
#  'The best answer is challenging yourself',
#  'To start with indulge in cardio',
#  'The key is to constantly keep challenging yourself',
#  'If you want to be a full-stack programer, you need to firs learn the fundamentals',
#  'Practicing and learning a lot',
#  'Just practice programming thoroughly',
#  'Because a lot of American food culture comes from the schedule on a farm',
#  'Eggs, like milk, were collected in the morning',
#  'Because some people confuse their opinions with facts',
#  'Some people hate to have their viewpoint challenged or changed and refuse to accept the truth',
#  'It increases her blood pressure',
#  'Viagra was originally designed to be a medication for low blood pressure',
#  'No, perfectly appropriate',
#  'The term you’re looking for is spiritualist, though you could specify atheistic spiritualist if you want',
#  'IF the $130K minimum wage for H-1Bs is passed it would apply equally to all states',
#  'It would be the same requirement for rural Mississippi as it would be for a high cost-of-living location like Palo Alto or Princeton',
#  'if you’re somewhat strict about these things, you might conclude these companies were lawbreakers and did not grow ethically',
#  'I could stand in the middle of 5th Avenue and shoot somebody and not lose any voters',
#  'HOWEVER , if she is a spy her handler would not allow this behavior',
#  '18 year old and older actors are typically more experienced and have a more public profile, which draws more people to the theater',
#  'Also, it’s a lot easier with paperwork and the logistics of participating in such a film',
#  'Life is hard because the universe was not designed to accommodate it',
#  'Not really',
#  "We don't look for a particular model, we look and observe driving behavior",
#  'With the Moon no longer there, the oceans of the world become much calmer',
#  'But the oceans would largely become serene',
#  'The first thing you want to do is engage your audience in a fun and playful way',
#  'You also want your potential consumers to have the feeling that they are part of some sort community',
#  'The Rosenbergs gave the nuclear secrets to the Soviet Union',
#  'Ethel and Julius Rosenberg betrayed the US by sharing information with the Soviet Union from Los Alamos laboratories',
#  'The quick and simple answer is because cereal is a quick and simple meal any kid can make themselves',
#  "It would not be nearly as ubiquitous of an item if is wasn't for the sugar conspiracy",
#  'A CCNA will get you hired',
#  'I think this is the most extraordinary collection of talent, of human knowledge, that has ever been gathered together at the White House, with the possible exception of when Thomas Jefferson dined alone',
#  'Each took a couple of years, so having a couple of full-time years to spare is probably the first requirement',
#  'The second requirement is to be dissatisfied with existing languages for some reason',
#  'I “like” submissive people when I want them to follow orders',
#  'I don’t “like” submissive people when it comes to friendships',
#  "Because people (atleast me) are not here for anybody's writing skills",
#  "It's not necessary to have great writing skills as long as the answer is serving the purpose",
#  'What bothers me most is when conservatives say things that aren’t at all conservative',
#  'I also don’t have a lot of respect for conservatives who seem only to care about money',
#  'I see a lot of hypocrisy amongst Christians who have become vicious in their hatred of Muslims, anger towards the government, and complete lack of virtue in both speech and practice',
#  'So combined those two answers together, Indonesia is a place where we eat a lot of exotic foods in the middle of rainforest',
#  'No',
#  "Of course you aren't",
#  'In no way, shape, or form are you ever required to donate blood',
#  'Because no one wants to feel betrayed and their trust being broken',
#  'No one wants to feel stupid for being trusting enough',
#  'If by “improve boob size” you are asking how to increase the size of your breasts, then breast augmentation surgery could be an option for you to look into',
#  'No, I don’t believe so',
#  'I don’t give a toss what the developers of a game wanted or intended for me to do in their game, I only care about what I can do',
#  'The best thing you can do is read in English everyday - read outside of your interests in particular',
#  'The President of the United States, as chief executive of the superpower and its military, was thus described as the "leader of the free world," basically by default of the weakness of the other democratic powers',
#  'Even as they recovered and rebuilt their military and economic strength, the U',
#  ' was undeniably the most powerful military force for democratic nations during the Cold War',
#  'To me, it makes more sense to go with a procedure which is permanent rather than something which is temporary, such as waxing, trimming, shaving etc',
#  'The more ideal option would be permanent hair reduction through laser, or electrolysis',
#  'When the startup’s finances allow it',
#  'When they need it',
#  'Not if your last name was, say, “Kennedy” or one of your parents was the CEO of a Fortune 100 company, or you were related to a World leader',
#  'A GPA on its own, even 4',
#  '0, is not going to do it',
#  "You'd become malnourished within a few days more than likely",
#  'You would also experience a great deal of constipation due to a lack of fiber as well as a myriad of differing illness (potentially including but not limited to scurvy, rickets, and weight gain) due to vitamin deficiency and the high fat content of deep fried nuggets',
#  "Eventually your body would begin to shut down due to lack of proper nutrition and you'd more than likely die",
#  'A problem with my car',
#  'Arranging a substitute, being late for work and getting the car repaired',
#  "But he's not the Emperor's match in terms of power, and he knows it",
#  'I eat meat largely because its delicious',
#  'I don’t believe that animals are “the same as humans”',
#  'My dietary choices are not generally guided by theological issues',
#  "That's the biggest sign in a relationship that it's destined to fail",
#  'As many others have said, the book seems problematic, though I expect it does explain the beliefs of its author',
#  'The author isn’t exploring the issue from a scientific point of view but instead approaching it in terms of his vision of Catholicism, one which disagrees with the official church stance',
#  'Prokaryotes and Chemoautotrophs are the earliest identified life organisms in the world dating to 4 billion yrs ago',
#  'The most important thing in life is the ability to handle love and trust and intimacy and sexuality',
#  'Hats for women went out of fashion about the same time that they did for men, in the 1960s',
#  'You should sell something for profit',
#  'Entrepreneurs find opportunities to fulfill the needs or wants of other people for a profit',
#  'This means that you first need to discover an opportunity, which you can do through research, then figure out the cost of the product or service that will fulfill the underlying need (by doing some more research), then calculating a price at which people would be willing to buy it, and give you enough profit to grow the business',
#  'Unlike India and most other countries,Pakistan is actually divided into 4 provinces,name Khyber Pakhtunkhva Region,Punjab,Sindh and Balochistan',
#  'Man, would I love to be in Gryffindor',
#  'But as my fellow Harry Potter loving friends have told me multiple times, I would more likely be in Ravenclaw',
#  'His metabolism is faster than yours',
#  'Everyone’s bodies are different, this is nothing new',
#  'You can get one to remember someone/something, you can get one because it looks pretty or cool, or a variety of other reasons',
#  'If you are so particular to eat a fruit in the morning, banana is the best fruit',
#  'They will realize it themselves someday',
#  "You want to forgive them because you want peace of mind and don't want to hold grudges against anyone in your life",
#  'Forgive because you are strong',
#  'You get stronger by giving your body a reason to get stronger',
#  'Liftings weights is one of the best ways to do this, but it is not the only way',
#  'You could, for example, use bodyweight exercises',
#  'You were justified, but you’re still at risk of getting into a lot of trouble',
#  'This concept does exist',
#  'It does happen',
#  'If she is not ready to even talk about your feelings (or lack thereof), it is better to let this girl go with dignity',
#  'No, Wikileaks is not derived from Wikipedia',
#  'Stop looking outward and look inward, into your heart',
#  'Money, so “they” say cannot buy happiness',
#  'Get a driver’s licence',
#  'As soon as we turn sixteen, we rush out to take the test and squeal when the license comes in',
#  'Permanently',
#  'Fingerprints are corrosive and can and do etch steel',
#  'It seems that the higher the polish the easier it is to leave a permanent one',
#  'It is not possible to fly a plane in space',
#  'In space, there is no air so none of these work',
#  "This, of course, lies on subjective views but I assume intelligent people enjoy anime more than others because it's their exit from the world we live in while being entranced by something that is usually intelligently created",
#  'The reason people talk this way is because they consider this to be “hip” and “trendy”',
#  'The media promotes saying these things',
#  'Celebrities say these things',
#  'I think a French exit would be he death knell for the EU',
#  'With them gone the dominoes start to fall',
#  'If you would like to see who visited your Facebook page, you can use SocialFans site',
#  'Usually prisoners are really tolerant of people with mental illnesses',
#  'They are treated well nowadays',
#  "Didn't use to be so, but they are now",
#  'You’ll get the occasional dirty look from more right-wing Americans, especially if you’re out in the countryside, and a fair number of people will probably assume you are trying to be “edgy” rather than actually expressing any real support of or understanding of, communist ideology',
#  'Yes surely he/she can write novels',
#  'You should have been well versed with vocabulary and must have good reading habits',
#  'They cause undue suffering to those hit by one and that is against the laws of war as set by the Geneva conventions but more importantly thinknof it likenthis the battlefield lifespan of a flamethrower operator was about 18 seconds',
#  'Breathe control',
#  'Maintaining your breathing is crucial to keeping your wits about you',
#  'Time is the 4th dimension of the universe, Time and space are interwoven, hence the phrase “Space-Time”',
#  'The common name would remain China',
#  'But there might be a dispute as to whether officially, it be called the People’s Republic of China (PRC) or the Republic of China (ROC)',
#  'The previous is preferred by the mainland whereas the latter is used by the island',
#  'This has been clearly laid out by DropBox executives in the past, and the primary reason was very clear: Cost control',
#  'There were other secondary reasons too, like looming AWS Managed Services, flexibility, Infrastructure control etc',
#  'Absolutely',
#  'Therefore gravity is indirectly powering any hydroelectric station',
#  'Tides are caused by gravity, and it is possible to generate power by harnessing tides',
#  'There’s nothing wrong with having sex before marriage, or just sex period, and never getting married',
#  'No doubt at all - The current reservation system is bad for India',
#  'If a system/process fails to achieve in 60 years what it was supposed to',
#  '… then it is a clear case of failure',
#  'Technically no',
#  'There is no way of proving the non-existence of things',
#  'Because that will result in an unpleasant and undesirable consequences',
#  'Other countries will considered that China does not have the ability to protect the sovereignty of its own country and that they would seek their chances to claim one of the Chinese land to be theirs or even start a war',
#  'So it is of crucial importance for the Chinese government to insist that Taiwan is just a province of China, not a country',
#  'Because there are only a very limited number of places available, and admission is very difficult',
#  "They had already completed filming Episode VIII, so they won't need Carrie Fisher for that",
#  "Star Wars has obsessively used the same actors to play characters, and when those actors weren't available, they used CGI (Leia and Tarkin in Rogue One)",
#  'There are no more barbarian hordes who want to destroy the places of higher learning, churches and so forth',
#  'Truly severe global warming leading to the starvation of billions could do it',
#  'Another possibility is a wave of religious imbecility that wipes out liberal democracy all over the world and replaces it with some kind of authoritarian theocracy',
#  "It wasn't seen as sexual because they're little kids",
#  'It was unheard of to think that a short skirt would be seen sexually rather than as something for a kid to run around in and get dirty',
#  "I don't think so they are fairer",
#  'They are not any different from rest of Indians',
#  'Heat is kinetic energy, the energy manifest in the molecular vibration of molecules',
#  'Energy is the ability to do work so heat is energy',
#  'The most reliable indicator is super-fluency with language',
#  'So to all those Quora newbies right here reading this I would recommend you to use the mute button Quora to block certain topics and people whom you feel are worthy of it',
#  'Yes',
#  'There should definitely be',
#  'So each imported movie or tv show is an english lesson',
#  'In school they try to teach us british english but we still sound more american',
#  "If your point and shoot is a Canon, buy a Canon, if it's a Nikon, buy a Nikon because you will be amazed at how familiar everything is",
#  "There is a lot of time available for reading in everyone's life",
#  'Lying in bed at night is a traditional time for reading',
#  'If you commute on public transit, have a lunch hour without work to be done or friends to visit -- all good times',
#  'Having something stolen from you',
#  'But the feeling of loosing an expensive item does put a hole in the heart',
#  'Zlatan was the best player in the title winning Milan side',
#  'If we factor in the performance at the international level, then Forlan has to be the best',
#  'The “Girl rating” algorithm you mentioned is Elo Rating Algorithm',
#  'He probably doesn’t even have insomnia at all',
#  'When you’re with him, all the distractions leave, and he has a peaceful sleep',
#  'But when somebody is with us, we cherish those moments and sleep along with them',
#  'But I suggest backing up your data, gathering your install media for any programs you want to keep, and then re-installing the OS from scratch',
#  'I mean a full re-format and install',
#  'No',
#  'The US would never do such a thing',
#  "The US also wouldn't want to give up trading partners",
#  'Yes from the scientific point of view, makes no sense to doubt it',
#  'So, is not only harder to fake than to do in reality, is impossible',
#  'One methodology for supressing vapour trails is to fly at very high altitudes where humidity is as low as possible, another is to fly lower in much warmer air',
#  "This is due to a whole variety of factors including male dominated societies and outdated notions about women's brains being fickle and simple (an idea which astoundingly survived the Victorians",
#  'It means he’s arrogant and entitled',
#  'He is being very condescending - assuming that you will be waiting around and available to him if and when he might decide to date you',
#  'He’s telling you openly that he sees you as an option',
#  'Yes, you can build muscle with light weights',
#  'They came into the world together, and seemed to have been nearly identical at an early age',
#  'The rest of the Realm isn’t good enough for them, except the Targaryens, and, frankly, they are both better looking than most people',
#  'It is narcissism on both parts from the get go',
#  'I do nothing unless that person is harassing me and/or people I know',
#  'Then, and only then, will I block & report',
#  'The specific answer is, Jesus is not black and that will never happen Jesus was once a person who have set his real foot on the soil of this planet he was no black he was a Jew, what confuse people?',
#  '“The term was coined by Id software within the context of its game,” that game being Doom',
#  'I would never stop loving my passion for writing',
#  'It takes time, lots of time',
#  'What helped was talking to a trusted friend who told me I deserved a lot better than a liar',
#  "They aren't strong they're organised and focused but if a side were to break that concentration they would have a good chance of being Chelsea",
#  'Kashmir already belongs to kashmiris and it is integral part of India at the same time',
#  'If your main priority is great battery life and performance then go for Redmi Note 4',
#  'If you don’t care about heating, camera lens getting scratches and below average battery life (almost half of competitors) but want great camera and latest Android updates than go for G4 Plus',
#  'Unfortunately, yes',
#  'Most of it’s due to the rise of secular humanist ethics and, along with them, the cancerous post-modernist philosophy: “Nothing really matters, so if it feels good, do it!',
#  'Absolutely, and still do it now',
#  'The biggest thing gun wrapping, or just covering with a blanket, did was greatly reduce chances of a light glaring off the gun',
#  'The short answer is yes, by any conventional definition of discrimination, treating one group differently than another group involves discrimination',
#  "You're a little blind like we've all been, but I assume you're spending most of your time together anyway so it's not crazy",
#  'The "right" religion is the one that serves you best, right up to the point that it tries to be imposed on everyone else',
#  'Answer is because they don’t',
#  'Indians are not killing their own Kashmiri people',
#  'Often they sleep in afternoon classes after they have eaten lunch',
#  'Eating releases a cascade of hormones to help metabolize food, including serotonin, which can make you sleepy',
#  'Proteins especially make you sleepy, but also foods like bananas release melatonin, which can make you sleepy',
#  "I think it's extreme, heartless, and idiotic, and I'm saddened by and ashamed of it",
#  'For the starters it is not so easy to learn a bike with all the techniques first day you touch it',
#  'Secondly it needs practice and a sense of balance which no one can teach you and you should earn it all by yourself',
#  'Lastly,if you are passionate about riding you can do anything and ride any motorcycle',
#  'Not usually',
#  "It's hugely expensive to do so",
#  "If the destination airport is new to the airline, it don't believe that it would be be uncommon that one or more pilots fly the approach and landing in a simulator to check there are no unusual things to think about",
#  'Used cars can definitely be a smart way to save money and/or change cars frequently without wasting too much money',
#  'Catholics believe that the authority to administer the Church of Jesus Christ and its ordinances (such as baptism and the sacrament) was passed down from Jesus to Peter and the Apostles to others and later Bishops and Popes and Cardinals and Priests in an unbroken succession',
#  'Protestants believe that the authority was lost somewhere along the way because the Catholic Church had become corrupt and was no longer teaching the pure Gospel that Jesus had taught',
#  'This isolated and well defended piece of land makes it easy and secure to hold Taliban and Al-Qaeda prisoners without interference',
#  'If we were to hold them in an allied country we would have to contend with their courts and their rulings',
#  'No one who knows has said anything at all',
#  'Using “mean of parental IQs”, as the standard guess, Barron is likely in the 120 to 130 range',
#  'Rice is one of the most popular grains in the world, and it’s packed with a ridiculously high amount of energy',
#  'Rice contains many essential vitamins, such as thiamin and niacin',
#  'It has to be this jaywalking thing',
#  'One day I thought about googling it, and found that in the US, aswell as most countries around the world, its illegal to cross the road if not at a marked crossing',
#  'I have been abroad and never heard the term jaywalking but it seems ridicualous that it is illegal to cross the road',
#  'It certainly seems that she’s encouraging you to invite her to spend some more time together',
#  'An abstraction can be applied to any specific circumstances that fit',
#  'Abstracting from many (many) specific examples, is computationally (brain-time) costly, probably on the order of 100x more difficult, and may lead to improper understandings and principles',
#  'Otherwise, class time is limited',
#  'There are already a lot of good answers here such as drinking coffee, something with sugar, taking breaks, taking short naps, studying with a friend, take a cold shower when you’re about to lose the fight to stay awake, and listening to upbeat music',
#  'One solution you might want to consider is taking Modafinil',
#  'App Inventor is a great resource for complete beginners that have never worked with code before',
#  'Hopefully he didn’t spend much of his life wasting it in preparation for an afterlife that he now knows is not coming',
#  'Instead, maybe he lived, and is content with what he did with the years he had',
#  'Sing your death song and die like a hero going home',
#  'Therapies indicated for treatment of gynophobia include exposure therapy, behavioral therapy, talk therapy, CBT or cognitive behavioral therapy',
#  'Speak with your parents about seeing your doctor who can refer to an appropriate specialist',
#  'You enhance your debugging skill when you encounter and solve problems',
#  'In order for that to happen you should challenge yourself by programming something you never did, you will surely have at least one difficulty',
#  'And finally, see code written by other good programmers, it will help you understand the efficient/ right ways to write code',
#  "I don't see why not",
#  'My sister and I shared a place when her boys were young, and if asked I always answered honestly',
#  'Thankfully YES, otherwise I would have had a tough time over the years',
#  'Most women respond to the confidence that a guy has and his personality, so if you have a great personality, a sense of humor and a boat load of confidence, then you should have your pick of potential girlfriends',
#  'No',
#  'They all say no to guys one time or the other',
#  'No is normal',
#  'It’s perfectly legal',
#  'There are laws about carrying knives (and other bladed potential weapons) in public without due cause, but you can make whatever bladed items you like on private property',
#  'Just don’t',
#  'So if you are interested in your child’s health and development, understand the effects of your behavior and don’t do that again!',
#  "I think she is weak for a conservative, she's too liberal in my view",
#  'I don’t see any protest coming from Indonesia government',
#  'It’s a well known facts that Singapore has a strong relationship with Israel',
#  'And it’s an undeniable facts that Indonesia has a strong business to business and military relationship with Israel',
#  "Take Bruce Lee's or the mixed martial artist's approach",
#  'The most important ones are (in no order) wrestling, jiu jitsu, muay thai, and boxing',
#  'More specifically, study the martial arts that are used in MMA fighting',
#  'Most of the times, Yes!',
#  'But yeah, I always write names of others and not mine so I doodle without worries ( and its more exciting when one of my classmate is caught because he has writen his name on desk while nobody knows who on Earth did that)',
#  "It is possible and can be beneficial to both languages you're trying to learn",
#  'However, this will not work on all two language combinations',
#  'There is no known proof of Goldbach’s conjecture',
#  'It\'s highly unlikely that there would be a cure for "cancer',
#  'Ensure Plus is effective',
#  'Also, pay closer attention to calories on the nutritional facts',
#  'Increase calorie intake with Ensure Plus or sneak in more pasta and you may notice a significant difference in a fairly short period of time',
#  'It would not be a good idea',
#  'A salaried employee is not paid by the hour',
#  'You can certainly Argue it’s a result of U',
#  'S foreign policy',
#  'Not to mention, the CIA gave birth to Osama Bin Laden and breastfed his organisation during the 1980′s',
#  'Former British Foreign Secretary, Robin Cook, told the House of Commons that Al Qaeda was unquestionably a product of Western intelligence agencies',
#  'They should stop cherry picking the teachings in the Bible and like taking the ones that serve their interests and dismissing those which don’t',
#  'May be because of the busy, competitive and internet addicted world?',
#  'Even if they make some friends, they are looked upon more as their competitors than buddies!',
#  'No, staying in USA without authorization is not a felony (in layman’s term: crime)',
#  'It is obviously a violation of the law —just like driving above the speed limit— but it’s a misdemeanor at worst',
#  "First and foremost I must tell you that that's perfectly normal, not smart, but perfectly normal",
#  'one way to improve your creativity is to expand the sphere of your interests',
#  'Tourette Syndrome is very exhausting as your body is always moving and you are always making noises and saying things',
#  'There is not much to say about Coprolalia except that it is hard to go out with it because sometime parents will say to you get way from my child as they don’t want there child to hear bad stuff',
#  "Commander Neal Armstrong was the first man to walk on the moon by virtue of the fact that the door prevented Buzz Aldrin from stepping out first, however because of the bulky suits neither of them managed to do the moonwalk on the moon so that still hasn't been done yet",
#  'We are disappointed, worried, sad',
#  'And we will never entirely trust you again',
#  'Well the easiest way, which may not produce results, is to upload it to  the Google Image Search engine',
#  'Being a vast land mass Russia spans both Asia and Europe and what is called Eurasia',
#  'Brown sugar is really no different, nutritionally, than white sugar',
#  'Both are essentially just calories and sweetness',
#  'The easiest way to explain it is that baking soda is a base—it’s alkaline',
#  'Baking powder is a mixture of baking soda and a dry acid, such as cream of tartar, and perhaps some cornstarch to help keep the two separate and dry',
#  'The Nazis shot people, but that wasted ammunition and was detrimental to the Nazi morale',
#  'The process was so efficient that a prisoner could arrive at a camp and be gassed 2 hours later',
#  'Gas was also cheaper than ammunition and faster than shooting or starvation',
#  'The best way to learn Guitar faster is to invest a good amount of time in practicing the Scales',
#  'Acturally, Quora is not a famous Website for most of the chinese netizen',
#  'So luckly, little influence give us a lax supervision',
#  'The ratio of the mass of any man made object to that of the Earth is so tiny that the effect is negligible',
#  'The mass which has permanently left the Earth probably amounts to a hundred tons or so - two or three day’s worth of meteorite arrivals',
#  'Air-to-Air Missiles from other jets',
#  'Surface-to-Air from the ground',
#  'I honestly don’t think confronting in any sense is a good idea',
#  'Considering the social backlash if he comes out, for whatever reason, it is his choice, and coming out, or not, is his',
#  'Expanded Universe: Sidious, due to force mastery and sheer ability',
#  'In canon, Sidious would still win, but that is just because of sheer experience',
#  'Scallops are very challenging because they vary week by week, day by day, and even batch by batch',
#  'Skin on fish seems to be a struggle for most people because you want it crispy',
#  'The British army at the time were professional in a way that most of the other European troops were not',
#  'But they did have good discipline and they did have strong musket drills and decent, well maintained weapons',
#  'Sociopaths are made, not born',
#  'They have circumstances in their lives, whatever they may be, that change their interaction in the world',
#  'EARLY in the day',
#  'Because the early hours of the day are the optimal time for your analytical brain to perform the most complex tasks (in the case of studying, these can be reading, comprehension, application, repetition)',
#  'As far as I know,a daily running of 15–20 mins in the morning,a healthy breakfast like sprouts,egg without yolks,oats',
#  'Light lunch',
#  'Pushups,chinups,burpees,squats,planks-these exercises dont require you to go to gym',
#  'Then just follow the way of life suggested by Buddhism and you are a Buddhist!',
#  'One of the best ways of dealing with these is to be proactive',
#  "Make sure your child isn't hungry, thirsty or tired",
#  'If you go out, make sure you have snacks and drink, and do not go out at nap time',
#  'Honestly, I’d say that Black people don’t really have privilege, and on the racial hierarchy, it’s the worst thing to be',
#  'In addition to the "humans and apes evolved from a common ancestor" answer, which is the key point, there\'s another misconception to tease out here: that evolution is a series of "X is replaced by Y" steps',
#  'The Sensex and Nifty are "indices of a stock market"',
#  'The Sensex is an indicator of all the major companies listed on BSE(Bombay Stock Exchange) which is situated at Bombay',
#  'The Nifty is an indicator of all the major companies listed on NSE (National Stock Exchange) which is situated at Delhi',
#  'My husband and I have constant fights about who’s friends do we hang out with',
#  'The law in many western countries considers marriage to be a particular form of economic union',
#  'If the marriage ends, each spouse is entitled to 50% of the value acquired during marriage (less any debts acquired during that time)',
#  'You have to take responsibility for everything that happens to you',
#  "Don't",
#  "Please don't",
#  "Finish your schooling (it won't be much longer if you are in 12th grade) and then you can ask anyone you choose to go out with you",
#  'If Hitler had not killed himself he would have eventually have been captured by the Russians if he had stayed in his Berlin bunker and eventually hung after the Nuremberg trials',
#  'So western allies tried to pacify Germany and Japan with other means, turning them into economical powerhouses',
#  'One exception from my residency training stands out, in which bile splashed into my face during a procedure involving the liver',
#  'I definitely felt the need to step away and wash up thoroughly',
#  'Wikipedia is the only one of those platforms which strives to not be biased or opinionated',
#  'Love means to serve the beloved person unconditionally',
#  'I serve you not with motive to enjoy you, what ever yours liking , they are mine, I do things because you like that',
#  "You don't find your soulmate, you develop one",
#  'It starts with noticing someone in your life who attracts you',
#  'An overdose of Benzos such as Diazepam or Lorazepam, alternatively an overdose of prescription sleeping tablets',
#  'I do not share my wife',
#  'But I’m not “sharing” her; she is choosing to have other lovers, and I’m totally okay with that',
#  'If people choose to be married but not monogamous, yes, that’s totally okay, as long as all the parties involved are on board with it',
#  'In english its called bootlicking',
#  'Become a political assistant of any high profile politician, you will be paid crores of black money packages',
#  'The answer is No',
#  "They don't want to, because they feel a part of India",
#  'The engineers that worked in my groups never really did their own development',
#  'Just go for Redmi Note 3 without any second thought ',
#  'Its a very powerfull device and at the same time power efficient too',
#  'Awesome battery life , decent camera pair under normal lighting conditions',
#  'Trump is not ending the Visa Waiver Program',
#  'However, aliens who do not require visas, such as most citizens of VWP countries, will be unaffected',
#  'Nothing is wrong with you',
#  "We sleep more when we don't have any work as such",
#  'To prevent dictatorial excesses like the Cultural Revolution',
#  'To prevent a CR-like reoccurrence, the cult of personality was almost completely abolished, power was distributed throughout the politburo instead of being concentrated in one man’s hands, and term limits were set',
#  'However, if she decided to do it no will object',
#  'She is a guest and, a queen and diplomatically immune',
#  "Like any genre that's new, rap takes time to appreciate",
#  "Many people don't like jazz because it too requires repeated exposure and careful listening",
#  'Rap is unique because you must listen to the words to understand it',
#  'The Element by Ken Robinson, which discusses how you don’t have to fit into the norm or a categorical box as society dictates but may find your calling in another talent that cannot be academically nor financially quantifiable',
#  'I also read The Alchemist many years ago and while I thought the writing was really simple and minimalist',
#  'Since this person is your parent, I would call them whatever they asked to be called',
#  'So if they ask to be called mom, dad, or Bridget Jones, I would hope that you would call them whatever they wished to be called',
#  "I'd vote for the better politician",
#  "In the end though, if they truly are identical, it shouldn't matter who I vote for",
#  'Almost all animals alive today are successfully evolved, apart from a few things like the tuatara which has been largely left behind by evolution because it lives on a sheltered, isolated island',
#  'According to the Global peace Index 2017, Iceland is the most chilled country',
#  'It would be too costly, but there is a bigger reason not to launch nuclear waste into space: safety',
#  "In part because there are a lot more religions than the one you're quoting from",
#  'Getting B’s or C’s will not work for Stanford, need to have very high grades and test scores',
#  'If you don’t have top grades, then you need to be a top athlete in some sport that the school wishes to recruit',
#  'Another helpful tip is if you are applying from an area that does not have alot of applications',
#  'Yes',
#  'If they make money, however, then ABSOLUTELY they should be taxed like any other business',
#  'Employees of the church should be taxed on their personal income just like anyone else',
#  'I would take it seriously snd will devise a plan to get better',
#  'I would employ everything- medical, psychological and complimentary therapies',
#  'Good to work on relationship with yourself',
#  'That is correct, yes',
#  'If you’re not allowed to do it, you can’t ask someone else to',
#  'Shabbat is supposed to be a day off for everyone — even your animals — and so it’s not fair to ask someone outright to do something that you can’t do',
#  'That said, if you can find your boss doing something illegal or vastly against company rules and discretely snap a photo of him/her doing it, print it out and leave it anonymously with HR',
#  'If you know your boss has a weakness for something illegal, create a situation where it would be easy for him/her to give in to temptation',
#  'Atheism is only the lack belief in any gods',
#  'You can eat a light lunch which will help',
#  'You can also build in a small amount of exercise: stretching, a short walk',
#  'You can also deliberately set a timer for a work period',
#  'Yes, Chamberlain was duped by Hitler, because he believed Hitler’s signature on an agreement meant something',
#  'Hitler gave his word, and Chamberlain accepted it as a matter of course',
#  'If that is your measurement we can say that Jennifer Aniston is at the top',
#  'For a few years after Friends it might have been a tie with Matthew Parry as he had quite a few Rom-Coms under his belt out the door',
#  'Targaryens are not impervious to fire',
#  'In fact, during the Dance of the Dragons, at least two Targaryens died from fire related wounds',
#  'Nursing and medicine are not the same professions',
#  'If you want to be a doctor, go be a doctor',
#  'If you want to be a nurse, go be a nurse',
#  "I, personally, wouldn't trust the doctors taking care of me if they figured out I was an organ donor",
#  'It’s not weird at all',
#  'People need to be comfortable in their own company; it’s a mark of maturity',
#  'I promise that no one will care or notice what you’re doing',
#  'You Should Only Use the Charger That Came With Your Device',
#  "I don't shop at Whole Foods because it's too expensive",
#  "My food tastes don't really align with their strengths, either",
#  'A lot of people would freak out and people would immediately seek shelter if they’re out in the cold',
#  'Then after a few days, if clothing reappeared, Goodwill would be inundated and people would happily stay nude on their own',
#  'Category theory is not considered controversial in any way',
#  'It is a fundamental part of mathematics since the 1950’s',
#  'Indefinitely',
#  "The ships ran out of ammunition and couldn't ram each other",
#  'I have visited Pakistan a few times and I think it suffers from a bad reputation ; much of the country is relatively safe for white people, the locals are, by and large, very friendly and helpful',
#  'I have visited three places that were once accessible to tourists (and are not now) that have a reputation for danger: Landi Kotal (the Pakistan-Afghan border town in the Khyber Pass), Darra Adam Khel, and Kharkhani Bazaar',
#  'So someone called you a loser, tell him/her you are not one',
#  'Japan is a friend of the US because it is politically, strategically and economically smart for it be friends with the US',
#  'To ensure the offender never has the ability to leave prison, even as a parolee',
#  'The extended right to abortion',
#  'The Romans consider it normal for a father to abort their children even after the birth',
#  'The way I started off was to use an app like Synthesia to learn a simple tune',
#  'I would recommend to learn from sheet music though',
#  'Take it slowly and you will gradally make progress',
#  'There really is no reason to embarrass him by telling you know',
#  'If you don’t want to go out with him, just tell him you’re not interested',
#  'No Absolutely not',
#  'Cheaters do change, but not overnight, and becoming a faithful romantic partner is a symptom of becoming a better, more honest person in general',
#  "Something that you said and didn't realize or they interpreted wrong",
#  'Also your tone of voice',
#  'Some people just have something about them that makes them seem rigid',
#  'In my lifetime Richard Nixon',
#  'However, overall probably the most despised President was Andrew Johnson',
#  'My answer is: because Prisoner of Azkaban was the first book when the series showed its potential',
#  'Prisoner of Azkaban was the first book in the series that really impressed me',
#  'The third book was the one that changed my mind',
#  'Darth Vader was always a pilot at heart',
#  "When he wasn't in a life support chamber or a bacta tank sulking, Lord Vader liked spending his free time in his palace on Coruscant tinkering with his personal Tie-Fighter",
#  'Pointless, perhaps, as well as probably unconstitutional because of the religion clause',
#  'It is ok for ANYONE to read Harry Potter',
#  'It is important that nobody refuses to read a particular book just because they consider themselves too young, or too old',
#  'No, and I don’t think they ever will',
#  'The personality type that seems to be related to computer science fields are largely introverted (myself included) and do not value parties, homecomings, proms, etc',
#  'The Rhodes Scholarship is the most competitive academic prize available to undergraduates (0',
#  '7% acceptance rate according to The Rhodes Scholarship Trust)',
#  'When you have no windows, you will have to create one',
#  'All things being equal Trump’s chances of being impeached are 4',
#  '5% so pretty low',
#  'Great executives get “it” done',
#  'The great executives are the ones that ultimately are able to push past obstacles and deliver results',
#  'You won’t like my answer but here goes ,get out, get a job',
#  'Go to work',
#  'Put your 2 year old in the hands of a loving responsible person who loves parenting',
#  'The difference is the feeling that exists behind the act',
#  'In other words, love making is still sex, but not all sex is love making',
#  'There is SO much evidence, from so many different research organisations, using a vast variety of methodologies, over a considerable time scale (we’re talking 1',
#  '5 million years here via analysis of ice cores) and even using different modelling, they ALL come to the same conclusion',
#  'You can’t prove a concept does not exist in reality',
#  'In other words, god is not proven… your job is done',
#  'I may be wrong but he can probably bench press his bodyweight easy',
#  'It is impossible to get work-life balance because balance is something that you do, not something that you have',
#  'You learn that as a dancer; balance requires constant effort (though we try to make it look effortless)',
#  'Just when you feel like you have figured out the right balance for one set of circumstances, they will shift again',
#  'It was very interesting work and satisfying, in that it unquestionably served the interests of my country',
#  'It is a career that affords you great opportunities to see the world, but it also demands much from families',
#  'She was christened Elizabeth Alexandra Mary',
#  'I would use YouTube as your tool of attracting a niche customer/fan base instead',
#  'You will receive a much greater and more consistent amount of money when you secure a deal with a business to sponsor your channel',
#  'Coming from another teen here, I think that your dad doesn’t need to tell you if they are dating for a few weeks, but he should be disclosing the information if it is a serious relationship',
#  'However, if he is bringing her over, yes he should absolutely be telling you',
#  "I personally believe that it's not a big deal whether she is virgin or not?",
#  "So, it's almost a compulsion to marry a non-virgin girl",
#  'If you have enough money/income of your own, then move out anyways',
#  'Find other female roommates to live with, perhaps, that may help with some of your parents’ concerns',
#  'Yes, your server will LOVE YOU to pieces if you pay the tip in cash!',
#  'Cash is king and will make your server do a happy dance',
#  'I always tip cash if I am able to',
#  'There are many methods that require proper work and knowledge and voila you can money online with a website, but before you earn you have to learn',
#  "Actually, the fastest way to improve your fingerstyle-picking is practicing your favorite professional fingerpickers' songs and imitating their skills",
#  'A large proportion of bigoted, homophobic or just plain stupid questions are posted by anonymous and a large portion of questions posed by anonymous are bigoted, homophobic or just plain stupid',
#  'Even when used for good questions, it detracts from the Quora community',
#  'But a huge portion of anonymous questions and answers do not need to be anon',
#  'No, that is entirely false',
#  'I eat meat as part of a balanced and varied diet',
#  'In most of the PSUs you will get managerial jobs only',
#  'Lastly i can say that you will learn mechanical,chemical,electrical what not everything , if you placed in a field location',
#  'I hate it when people are late',
#  'If you are late it tells me that you think my time is not as valuable as yours',
#  "Simply put, their inventions aren't advertised",
#  "And, if it's an ancient invention, the inventor is often portrayed as a white person",
#  'Obsessive-compulsive disorder, or OCD, is an anxiety disorder that generally causes extreme discomfort',
#  'Much better quality of results due to the PageRank algorithm',
#  'Consideration for the user, in the form of a streamlined minimalist interface with non-intrusive ads',
#  'I would go with William Marshal whose skill was well documented and acknowleded in Late Medieval Europe',
#  "So we can't even reach the speed of light",
#  'Any way, find a speech therapist and stick to them',
#  'All others stuff like speech therapists, supporting environment is also essential, but nothing will ever work (like in my case), if you give up (which I did)',
#  'Yes',
#  'A lot of times actually',
#  'I am not able to recall any particular incident but I am sure I have been there',
#  'You just need to learn a few things first',
#  'Don’t worry about what the other guys do',
#  'Overcome shyness by asking three questions to anyone you are interested in',
#  'The best doctor for liver cancer in Mumbai is probably me',
#  'And I can be easily contacted in the hospital',
#  'Well no you didn’t do anything wrong',
#  'You were just being more blunt in your approach',
#  'If the work is done and if he would be able to be alive after a while, why not',
#  'I do not recommend such a work regime after 30 years old, BTW',
#  'The only way to change someone’s mind is to give them what they think they want and make them think you are on their side',
#  'You have to clean up your own messes with them',
#  'The best way to kill the politicians is to be politician and beat them in thier own game',
#  'You beat them in politics,what is left is just a person no more politician',
#  "We don't want a separate nation",
#  "So we don't want a separate country",
#  'In the United States this is a Federal felony, and you can go to jail for up to five years(and probably a hefty fine too, in addition to state charges)',
#  'Yes, different people did so',
#  'I responded no, not interested',
#  'In some extreme cases I said no and explained that if there would any repeated try, I would consider it as aggressive assault and act appropriately',
#  'One of the easiest things you can do to learn English faster is to read as much as you can',
#  'Read things all the time',
#  'Because he’s not as courteous and gracious as she is',
#  'He’s a joker, and some of his jokes are insulting or racist',
#  'He breaks the boundaries of formal protocol required by diplomacy, while she is the consummate diplomat',
#  "Because most of the people who write movies where someone needs protecting are men, and everyone wants to be the hero of the story they're writing",
#  'I doubt that modern GPS satellites have such a “switch” built into them, as the doubts of the engineers have already been settled',
#  'Dopamine levels and the structure of dopamine receptors underlie this temperament difference between Introverts and Extraverts (On the Psychobiology of Personality)',
#  'It is for me, but not in the way you probably wish for',
#  'He got rid of anybody whom he even thought might be opposed to his views, and he bribed the remainder with large payments, along with an implied threat that something bad would happen to them or their families if they tried to quit',
#  'He also surrounded himself with fanatically loyal bodyguards',
#  "Of course we'll never know for sure",
#  'So it seems likely that at least some slave holders would have continued to profit from slavery for at least another 100 years',
#  'For sure, a lot more people would have lived in slavery if it had not been abolished during the Civil War',
#  'My personal recommendation is the You-Dont-Know-JS series by Kyle Simpson along with all of the associated video training that he does',
#  'An engine is a framework',
#  'It is the empty shell of a complete game, with all the content removed, waiting for the developer to provide code and artwork to complete the game',
#  'Then that means that you’re just an attractive person — either body-wise or personality-wise, to those girls',
#  'Working on NP-Hard problems is probably the most difficult because for that class of problems there is almost by definition no optimizing function that you can use to make life easier',
#  "I don't think it was rigged, but the internet is certainly exploding with conspiracy theories to try to convince people otherwise; That final touchdown should not have been awarded to the Patriots",
#  "That just doesn't happen in pro football, does it?",
#  'Milind Soman, a Bollywood actor completed this race in 15 hours and 19 minutes at the age of 50',
#  'sweetie, never do the revenge on your ex',
#  'leave it to karma, people who do you wrong will get their rewards',
#  'Take advanced classes as soon as you can',
#  'Avoid gossip and negativity AT ALL COSTS',
#  'Start taking your interests and hobbies seriously']

# %% [markdown]
# # Rule 2

# %%
# For each sentence, find if the combination exists
imper_q = []
for sentence in sentences_q:
    if check_imperative_r2(combinations, sentence):
        imper_q.append(sentence)
        
print(len(imper_q))
# Out:
# 71

# %%
op_filename = os.path.join(OP_DIR, dataset, 'imperative_rule2.txt')

with open(op_filename, 'w') as op:
    for sent in imper_q:
        op.write(sent+'\w')

# %%
imper_q
# Out:
# ['So in a buffet situation, you can buy larger quantities from vendors and save a huge amount',
#  'If you go through the profiles and lives of JEE Advanced toppers of last few year, you will find half or them or more cracking IIT JEE without having any coaching',
#  'IF the $130K minimum wage for H-1Bs is passed it would apply equally to all states',
#  'It would be the same requirement for rural Mississippi as it would be for a high cost-of-living location like Palo Alto or Princeton',
#  'if you’re somewhat strict about these things, you might conclude these companies were lawbreakers and did not grow ethically',
#  "It would not be nearly as ubiquitous of an item if is wasn't for the sugar conspiracy",
#  'The best thing you can do is read in English everyday - read outside of your interests in particular',
#  'You would also experience a great deal of constipation due to a lack of fiber as well as a myriad of differing illness (potentially including but not limited to scurvy, rickets, and weight gain) due to vitamin deficiency and the high fat content of deep fried nuggets',
#  'You should sell something for profit',
#  'This means that you first need to discover an opportunity, which you can do through research, then figure out the cost of the product or service that will fulfill the underlying need (by doing some more research), then calculating a price at which people would be willing to buy it, and give you enough profit to grow the business',
#  'You can get one to remember someone/something, you can get one because it looks pretty or cool, or a variety of other reasons',
#  'They will realize it themselves someday',
#  'I think a French exit would be he death knell for the EU',
#  'If you would like to see who visited your Facebook page, you can use SocialFans site',
#  'Yes surely he/she can write novels',
#  'You should have been well versed with vocabulary and must have good reading habits',
#  'Other countries will considered that China does not have the ability to protect the sovereignty of its own country and that they would seek their chances to claim one of the Chinese land to be theirs or even start a war',
#  "If your point and shoot is a Canon, buy a Canon, if it's a Nikon, buy a Nikon because you will be amazed at how familiar everything is",
#  'The US would never do such a thing',
#  'He is being very condescending - assuming that you will be waiting around and available to him if and when he might decide to date you',
#  'Yes, you can build muscle with light weights',
#  "They aren't strong they're organised and focused but if a side were to break that concentration they would have a good chance of being Chelsea",
#  'Most of it’s due to the rise of secular humanist ethics and, along with them, the cancerous post-modernist philosophy: “Nothing really matters, so if it feels good, do it!',
#  'Secondly it needs practice and a sense of balance which no one can teach you and you should earn it all by yourself',
#  'Lastly,if you are passionate about riding you can do anything and ride any motorcycle',
#  "If the destination airport is new to the airline, it don't believe that it would be be uncommon that one or more pilots fly the approach and landing in a simulator to check there are no unusual things to think about",
#  'One solution you might want to consider is taking Modafinil',
#  'In order for that to happen you should challenge yourself by programming something you never did, you will surely have at least one difficulty',
#  'And finally, see code written by other good programmers, it will help you understand the efficient/ right ways to write code',
#  'Most women respond to the confidence that a guy has and his personality, so if you have a great personality, a sense of humor and a boat load of confidence, then you should have your pick of potential girlfriends',
#  'There are laws about carrying knives (and other bladed potential weapons) in public without due cause, but you can make whatever bladed items you like on private property',
#  'Increase calorie intake with Ensure Plus or sneak in more pasta and you may notice a significant difference in a fairly short period of time',
#  'It would not be a good idea',
#  'You can certainly Argue it’s a result of U',
#  'They should stop cherry picking the teachings in the Bible and like taking the ones that serve their interests and dismissing those which don’t',
#  'In canon, Sidious would still win, but that is just because of sheer experience',
#  'They have circumstances in their lives, whatever they may be, that change their interaction in the world',
#  "Finish your schooling (it won't be much longer if you are in 12th grade) and then you can ask anyone you choose to go out with you",
#  'If Hitler had not killed himself he would have eventually have been captured by the Russians if he had stayed in his Berlin bunker and eventually hung after the Nuremberg trials',
#  'Become a political assistant of any high profile politician, you will be paid crores of black money packages',
#  'Rap is unique because you must listen to the words to understand it',
#  'Since this person is your parent, I would call them whatever they asked to be called',
#  'So if they ask to be called mom, dad, or Bridget Jones, I would hope that you would call them whatever they wished to be called',
#  "In the end though, if they truly are identical, it shouldn't matter who I vote for",
#  'It would be too costly, but there is a bigger reason not to launch nuclear waste into space: safety',
#  'If they make money, however, then ABSOLUTELY they should be taxed like any other business',
#  'If you’re not allowed to do it, you can’t ask someone else to',
#  'Shabbat is supposed to be a day off for everyone — even your animals — and so it’s not fair to ask someone outright to do something that you can’t do',
#  'That said, if you can find your boss doing something illegal or vastly against company rules and discretely snap a photo of him/her doing it, print it out and leave it anonymously with HR',
#  'If you know your boss has a weakness for something illegal, create a situation where it would be easy for him/her to give in to temptation',
#  'You can eat a light lunch which will help',
#  'You can also build in a small amount of exercise: stretching, a short walk',
#  'You can also deliberately set a timer for a work period',
#  'For a few years after Friends it might have been a tie with Matthew Parry as he had quite a few Rom-Coms under his belt out the door',
#  'You Should Only Use the Charger That Came With Your Device',
#  'Take it slowly and you will gradally make progress',
#  'When you have no windows, you will have to create one',
#  'You can’t prove a concept does not exist in reality',
#  'I may be wrong but he can probably bench press his bodyweight easy',
#  'Just when you feel like you have figured out the right balance for one set of circumstances, they will shift again',
#  'You will receive a much greater and more consistent amount of money when you secure a deal with a business to sponsor your channel',
#  'Coming from another teen here, I think that your dad doesn’t need to tell you if they are dating for a few weeks, but he should be disclosing the information if it is a serious relationship',
#  'However, if he is bringing her over, yes he should absolutely be telling you',
#  'There are many methods that require proper work and knowledge and voila you can money online with a website, but before you earn you have to learn',
#  'In most of the PSUs you will get managerial jobs only',
#  'Lastly i can say that you will learn mechanical,chemical,electrical what not everything , if you placed in a field location',
#  'If the work is done and if he would be able to be alive after a while, why not',
#  'In the United States this is a Federal felony, and you can go to jail for up to five years(and probably a hefty fine too, in addition to state charges)',
#  'One of the easiest things you can do to learn English faster is to read as much as you can',
#  'Working on NP-Hard problems is probably the most difficult because for that class of problems there is almost by definition no optimizing function that you can use to make life easier',
#  'Take advanced classes as soon as you can']

# %%
dataset = 'quora_QAD'
ip_path = os.path.join(IP_DIR, dataset)
op_path = os.path.join(OP_DIR, dataset)

op_filepath = os.path.join(op_path, 'imperatives.txt')
with open(op_filepath, 'w') as fp:
    for sent in imper_q:
        fp.write(str(sent) + '\n')

# %% [markdown]
# # Rule 1

# %%
#load libraries and environments
import spacy
from spacy import displacy

import en_core_web_lg
nlp = en_core_web_lg.load()

#rule: Has a verb in its lemma (base) form and is the root and does not have any subject child in it's dependency structure
def root_verb_in_lemma_nosubj(sent):
    doc = nlp(sent)
    cond1 = False
    cond2 = True
    for token in doc:
        if token.dep_=='ROOT' and token.pos_=='VERB' and token.text.lower() == token.lemma_:
            cond1 = True
            #print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
        if token.dep_ == 'nsubj':
            cond2 = False   
    return (cond1 and cond2)

# %%
# For each sentence, find if the combination exists
imper_q = []
for sentence in sentences_q:
    if root_verb_in_lemma_nosubj(sentence):
        imper_q.append(sentence)
        
print(len(imper_q))
# Out:
# 14

# %%
imper_q
# Out:
# ['To start with indulge in cardio',
#  'Just practice programming thoroughly',
#  'Stop looking outward and look inward, into your heart',
#  'Sing your death song and die like a hero going home',
#  "Take Bruce Lee's or the mixed martial artist's approach",
#  'More specifically, study the martial arts that are used in MMA fighting',
#  'Also, pay closer attention to calories on the nutritional facts',
#  'Just go for Redmi Note 3 without any second thought ',
#  'To prevent dictatorial excesses like the Cultural Revolution',
#  'Go to work',
#  'Any way, find a speech therapist and stick to them',
#  'Read things all the time',
#  'Avoid gossip and negativity AT ALL COSTS',
#  'Start taking your interests and hobbies seriously']

# %%
op_filename = os.path.join(OP_DIR, dataset, 'imperative_rule1.txt')

with open(op_filename, 'w') as op:
    for sent in imper_q:
        op.write(sent+'\w')
