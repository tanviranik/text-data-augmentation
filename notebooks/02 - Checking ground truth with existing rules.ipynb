# %%
import pandas
import os
import re
from collections import Counter
import spacy
from spacy import displacy
import en_core_web_lg
import numpy as np

# %%
# Directories

IP_DIR = '../data/input/imperatives/ground_truth/'
OP_DIR = '../data/output/imperatives/ground_truth/'

# %%
# Read input
ip_file = 'imperatives_github.txt'
op_file = ''

# %%
def preprocess_text(text):
    # text = text.replace('@', '')
    text = text.replace('\n', ' ')
    # text = text.replace('#', '')
    text = text.replace('RT ', '')
    text = text.translate ({ord(c): ' ' for c in "!@#$%^&*()[]{};.:,/<>?\|`~-=_+"})
    
    removeSpecialChars = text.translate ({ord(c): " " for c in "!@#$%^&*()[]{};:,/<>?\|`~-=_+"})
    
    text = re.sub(r'http\S+', '', text) #Remove URLs
    text = re.sub('([^\x00-\x7F])+', '', text) # Remove non-english characters
    text = re.sub(' +', ' ', text) # Remove multiple spaces
    
    text = text.strip()
    
    return text

# %%
imperatives = []

ip_filepath = os.path.join(IP_DIR, ip_file)

with open(ip_filepath, 'r') as ip:
    for sentence in ip:
        sentence = preprocess_text(sentence)
        imperatives.append(sentence)

# %%
imperatives
# Out:
# ['Remember the test date',
#  'Live in peace',
#  'Include the required attachement s',
#  "Don't follow me",
#  'Do not eat in class',
#  'Kill the butterfly',
#  'Take me to the library',
#  'Find out what you like to do most and really give it a whirl',
#  'Believe me',
#  'Move around town',
#  'Lets take a walk',
#  'Dont stop me now',
#  'Stop talking now',
#  'Do not smoke in your room',
#  "Don't you talk to me like that",
#  "Don't worry be happy",
#  'Eat your veggies',
#  'Let them cool',
#  'Take your coat off',
#  'Power the world',
#  'Stop and Go',
#  'repair your camera',
#  'Write read do what you need',
#  'Dont touch me',
#  'Mix together sugar and salt',
#  'Lock the door',
#  'Rise against the tyrannical government',
#  'Make up your mind to pool your resources and get the moust out of your remaining years of life',
#  'Driver carefully',
#  'have a safe trip',
#  'bring me a suitcase from my closet',
#  "Don't wait for my answer get started right away",
#  'give me your full name please',
#  'You better be quit',
#  'Eat them with milk',
#  'meet me at the town square',
#  'buy now while supplies last',
#  'Run for cover',
#  'Buy a dog',
#  'Enjoy some fresh apples',
#  'Pass through the intersection and take a right in 2 miles',
#  'Start a fire with your bare hands',
#  'change your clothes after playing outside',
#  'Write an email to your boss',
#  'Learn your lessons',
#  'Mop the floor',
#  'Play ball',
#  'Give us the gate key',
#  "Give me a few weeks I'll get back to you when I have time",
#  'Cancel the meeting',
#  'Be nice to your brother',
#  'Open the window',
#  'Keep working',
#  'be nice',
#  'Believe me',
#  'Wait for it',
#  'Write in Irish',
#  'Stand in line',
#  'Live in balance with nature',
#  'Speak freely and spread the word',
#  'Be sure to clean your weapon',
#  'Return the slaves',
#  "speak up I can't hear you",
#  "I'd be grateful if you didn't tell anyone about this",
#  'You watch your mouth young man',
#  'tell her I need her right now',
#  'Make me a cup of tea',
#  'Have a coke and a smile',
#  "Don't go out on the ice",
#  'buy now while supplies last',
#  'Have fun at the fair tonight',
#  'have a break',
#  'Buy a kitkat',
#  'Get out of my way',
#  'stop playing with your food',
#  'Save Ferris',
#  'Lead the pack',
#  'Speak what you think now in hard words and tomorrow speak what tomorrow thinks in hard words again though it contradict every thing you said today',
#  'please lower your voice',
#  'Cancel the order',
#  'Help the poor',
#  'First boil some water',
#  'pass the bowl of potatoes',
#  'Sit be quite',
#  'Feed the hungry',
#  'have fun tonight',
#  'put the cake out to cool',
#  'Get out',
#  'Please be quit',
#  'Take if you must this little bag of dreams',
#  'Report on what you find',
#  'love your enemies',
#  'Work to achive the goals',
#  'just do it',
#  'Let this generation have theirs',
#  'buy one and save 50 on your next purchase',
#  'Enjoy your meal',
#  'Be kind for everyone you meet is fighting a hard battle',
#  'Shop without me',
#  'Carry by hand gun',
#  "Don't eat my grapes",
#  'feel free to text me later',
#  'Speak in spanish',
#  'Heat the pan with oil',
#  'Take notes while listening',
#  'choose the German Sheperd over the huskey',
#  'please find my yellow leotard',
#  "Don't press that button",
#  'Launch the missles',
#  'Then pour the water into a cup',
#  'Cut out the cookies with a cookie cutter',
#  "Don't eat the cookies",
#  'Remember to wash under your armpits',
#  'Let the cookies brown before taking them out',
#  'call the doctor',
#  'Take me home',
#  'Enrich the poor',
#  'consider the red dress',
#  'Watch the videos and report back',
#  'Dont take things too seriously',
#  'come with me',
#  'Read every day something no one else is reading Think every day something no one selse is thinking Do every day something no one else would be silly enough to do It is bad for the mind to be always part of the unanimity',
#  'Unloose the cord and they will wrap you round',
#  'Put down the spoon',
#  'Be careful',
#  'Wait for me',
#  'tell me what you think',
#  'lets take a walk on the wild side',
#  'Paint the door',
#  'Look for the painted lady',
#  'Cure the sick',
#  'Silence',
#  'Throw the ball',
#  'Shop on sundays',
#  'Silence please',
#  'Dream big',
#  'Swich off your cell phones',
#  'Turn off your phones',
#  'Remove any batteries from your luggage',
#  'Dont text me',
#  "Don't beat him",
#  'do not kill',
#  'Do not waste your time',
#  'After that add a little milk',
#  'May I suggest the black suit',
#  'Put down the knife',
#  'Go to the edge of the cliff and jump off Build your own wings on the way down',
#  'Eat logs of popcorn',
#  'black me out',
#  'Play the guitar for me',
#  'Stand up',
#  "Let's face it",
#  'Do take a seat',
#  'please hand me the keys',
#  'Work in pairs',
#  'Please tidy up your room',
#  'Fetch a glass of water',
#  'Complete the exercies',
#  'tack the package before you leave',
#  'Slice the apple',
#  'open the back door',
#  'Question everything',
#  'join our table during the wedding',
#  'play nice in the sandbox',
#  'Roll out your cookie dough',
#  "Don't forget to take your passport with you",
#  'Forget all about it',
#  'Dont steal the cookies from the cookie jar',
#  'please send the nurse in',
#  'Tell me the story of your life',
#  'Stir in the coffee',
#  'do not bear false witness against thy neighbor',
#  'pay me',
#  "Don't stay out too late",
#  'Switch off the AC',
#  'Listen to the audio',
#  'Keep your cell phones or laptops closed',
#  'Move out of the way',
#  'Try to skip the first step',
#  'Please join my wife and I for dinner',
#  'All trading should occur on the Nile',
#  'Fake it or make it',
#  'Clean the desk',
#  'Have a piece of cake',
#  'Move quickly',
#  'Run fast',
#  'Write a letter to the warden',
#  "Come on Mary I'm waiting",
#  'come and celebrate the festivies before the night of the dance with me',
#  'come to the ball with me',
#  'do not turn left on red',
#  'play the song Mercy Me by Alkaline Trio',
#  'Wash the white clothes on Monday and put them on the stone heap wash the color clothes on Tuesday and put them on the clothesline to dry dont walk barehead in the hot sun',
#  'If this is coffee please bring me some tea but if this is tea please bring me some coffee',
#  'Go up to the board',
#  'Be a late riser Lazy men are always looking for an easier way be lazy',
#  'Dont forget me',
#  'Launch Firefox',
#  'Relax',
#  'complete these by tomorrow',
#  'Always remember who your boss is',
#  'come with me to church',
#  'Continue to deliver on your obligations',
#  'Play me a tune from your trumpet',
#  'Do not make a noise',
#  'Take your medicines',
#  'Fetch me a glass of water',
#  'Write your name on the exam',
#  'Pause the song',
#  'Dont look back',
#  'hurry',
#  'Hurry up',
#  'Roar roar roar Henderson Sungo Do not be afraid Let go of yourself Snarl greatly Feel the lion',
#  'Eat the lunch full',
#  'Wash your hands before eating',
#  'Stop the bus',
#  'Help me',
#  'Do not miss your class',
#  'Finish your task',
#  'Promise that you will do what you need to do',
#  'March forward',
#  'Do not eat in class',
#  'Walk to the corner turn left and cross the road',
#  'Try again next time',
#  'Complete these files by tomorrow',
#  'Write a text to your wife',
#  'let them eat cake',
#  'Use this website',
#  'Retreat to England',
#  'shut the door',
#  "Remember what it's worth to you",
#  'Turn around in 300 meters',
#  'Play the song alive by ima robot',
#  'Do not condemn the judgement of another because it differs from your own',
#  'Play hard work hard',
#  'Stay alive and avoid zombies',
#  'Come out with us tonight',
#  "Don't ever speak to me like that again",
#  'Poison the waters supply',
#  'Always play where I can see you',
#  'Change the dirty diapers',
#  'Touch the great artery Feel it bound like a deer in the might of its lightness and know the thunderless boil of the blood Lean for a bit against this bone It is the only memento you will leave to this earth Its tacitness is everlasting In the hush of the tissue wait with me for the shaft of pronouncement Press your ear against this body the way you did when you were a child holding a seashell and heard faintly the half remembered longed for sea',
#  'Always remember the person who has been nice to you',
#  'do good at school',
#  'Promise me',
#  'Close the door please',
#  'Fold the blanket',
#  'stop',
#  'Raid the Berber people',
#  'Make chocolate chip cookies for christmas',
#  'halt',
#  'turn right on red',
#  'honor your father and your mother',
#  'Hand over the assignment',
#  'Set the temperature 1 degree higher',
#  'Meet me outside the venue',
#  'Switch on the fan please',
#  'Write your personal manifesto',
#  'Enjoy life',
#  'Skip song',
#  'Note it down',
#  'Respect the elders',
#  'Turn on the radio',
#  'Look away',
#  'let the rack dry',
#  'when buying cotton to make yourself a nice blouse be sure that it doesnt have gum on it because that way it wont hold up well after a wash soak salt fish overnight before you cook it',
#  'Play the song test',
#  'Please go on reading',
#  'Let the water boil for at least fifteen minutes',
#  'Watch your step',
#  "Don't work alone on the assignment it will be much more difficult",
#  'Do Exercise daily',
#  'Exercise daily',
#  'Redo the translation',
#  'Assist in the discovery',
#  'Flip the table',
#  'Consider the lily',
#  'Invade france from the north',
#  'stop eating too much',
#  "Don't tease him",
#  "don't be late for dinner",
#  'This is mandatory',
#  'Set the temperature to 80',
#  'Swing wide',
#  'Check your email',
#  'Work Hard',
#  'Continue to work with the faith that unearned suffering is redemptive',
#  'Boil the turkey in vinegar',
#  "Don't Drink",
#  'Steep turn go slow',
#  'Open firefox',
#  'Shoot straight',
#  'Run faster',
#  'Turn off the radio',
#  'Clean the bathrooms',
#  'Meet back here after shopping',
#  'Be there at 4am',
#  'Drink is cool with honey',
#  'Skip this song',
#  'call me after 10am',
#  'Redo all the work',
#  'Call me maybe',
#  'Play the song "test"',
#  'Take a note',
#  'Keep hanky in pocket',
#  'Go back to Mississippi',
#  'stop',
#  'tell her you did not do it',
#  'Listen closely my friends',
#  'Never speak to me like that again',
#  'Help in the arrest',
#  'Drink a bourbon',
#  'Load your weapon',
#  'Please close the door',
#  'Wake me up on the weekend',
#  'Study hard for the math exam',
#  'Turn right in 500 feet',
#  'keep your friends close but your enemies closer',
#  'Launch Google',
#  'Drive to the roundabout and then turn left',
#  'Stop that',
#  'Collect nice books',
#  'Work hard play hard',
#  'Apply the glue thinly and leave it for ten minutes',
#  'Get Lost',
#  'Keep an eye on the time',
#  'Leave the class',
#  'Switch off the lights',
#  'Pass the book please',
#  'Please grill the sandwich',
#  'Maintain silence',
#  'Stay ahead',
#  "Don't let the lights get turned on",
#  'Let the dog out for play',
#  'Reach for the sky',
#  'Stop the track',
#  'Slap the naughty boy',
#  "You needn't give me a lift I will go by train",
#  'Overhaul the passages',
#  'do not left turn',
#  'Remember the Sabbath day by keeping it holy',
#  "Don't think about the future",
#  'Stop feeding the lions',
#  'Drink a port',
#  'Fill in the blanks',
#  'do not U turn',
#  'Turn right in 200 feet',
#  'Write an email to austin saying "You\'re the best"',
#  'Crouch under the wall then slide under',
#  'complete a u turn',
#  "Let the river rock you like a cradle Climb to the treetops child if you're able Let your hands tie a knot across the table",
#  "Come and touch the things you cannot feel And close your fingertips and fly where I can't hold you Let the sun rain fall and let the dewy clouds enfold you And maybe you can sing to me the words I just told you If all the things you feel ain't what they seem And don't mind me 'cause I ain't nothin' but a dream",
#  'Have a safe journey',
#  'Iron the shirt',
#  'Call me tomorrow',
#  'Listen before you speak',
#  'Do not come home late',
#  'Wear your gold necklace with that dress',
#  'Remind me in 10 days to email Austin',
#  'Swing hard johnny',
#  'Find the document titled "test"',
#  'Wake me up when suptember ends',
#  'Summarize the news for me',
#  'Smile for the camera',
#  'Complete the photo shoot',
#  'Launch Safari',
#  'go',
#  'Check if the laundry is dry',
#  'Fold your laundry',
#  'Let it occur then arrest them',
#  'walk for the minimum',
#  'clean the sidewalk',
#  'Call your parents on sunday',
#  'Discover the fall of the Roman Empire',
#  'go back to Alabama',
#  'May God bless you',
#  'Cook the steak well done',
#  'Please go and meet me at the middle of the dance floor after you perform your song',
#  'Turn on the kitchen light',
#  'talk to the hand',
#  'Stop feeding the dog from the table',
#  'Come around and see me some time',
#  'Save our Souls',
#  'Hit the ball',
#  'Use the big red nipple to move around',
#  'Complete all your work or else',
#  'Please leave',
#  'Fezzik tear his arms off',
#  'Extract the information you can',
#  'Get to bed on time',
#  'Work fast',
#  'Run fast',
#  'Skip to the next track',
#  'Find the document called "google"',
#  'Sleep well',
#  'Throw the ball',
#  'Get vaccinated before the age of twelve months',
#  'stir toegether flour baking soda and baking powder',
#  'Talk to me about dan',
#  'Take a taxi',
#  'Write an email to john saying "This is a test email "',
#  'Ask question if you have any',
#  'Eat something',
#  'Do your worst to me',
#  'Drink lots of water',
#  'Bring that to me',
#  'Find the lost treasure',
#  'go back to South Carolina go back to Georgia',
#  'Give me a new TV',
#  'Turn left at the intersection',
#  'Do not honk',
#  'Show me emails from Austin',
#  'Do not make the naughty list',
#  'Turn off the living room lights',
#  'cross the pedestrian lane do not jay walk',
#  'Complete mowing the lawn',
#  'Crack the game',
#  'sit in a semicircle',
#  'Clap',
#  'Put your hand into the bag',
#  'break a leg',
#  'Tell me about the weather',
#  "Don't eat all the cookies",
#  'Keep Calm and Carry On',
#  'Honk if you like my driving',
#  'stop yelling',
#  'run',
#  'Become who you need to be',
#  'Please tidy your room',
#  "let's eat",
#  'run for your life',
#  'go back to Louisiana',
#  'Find documents from June 1st on',
#  'pour me a glass of bourbon',
#  'Play me a short clip',
#  'Improve yourself or kiss yourself goodbye',
#  'be there at five',
#  'Roll the dice',
#  'Go to bed early',
#  'Close your eyes when you run away',
#  'Leave me here alone to collect my things',
#  'Eat your popcorn',
#  'Lend me a dollar',
#  'Please open the door would you',
#  'Crack your iphone',
#  "Don't trouble the children",
#  'shut the front door',
#  'Complete your work on sunday',
#  'Clear this room by tomorrow morning',
#  'Turn the record over',
#  'Pack enough food for our adventure',
#  'Ask for more work when you are done',
#  'Do what I tell you to do',
#  'Tell me whats in your wallet',
#  'go back to the slums and ghettos of our northern cities knowing that somehow this situation can and will be changed',
#  'Delete as much as you can',
#  'Give me a Robert Heinlein quot',
#  'Find the remote',
#  "Don't feed the dog",
#  'Have a good day',
#  "Shut up Brain or I'll stab you with a Q tip",
#  'tell me what you think',
#  'please join me at the after party',
#  'be kind to your neighbors',
#  'Plant enough trees for the summer',
#  'Come over here let me show you',
#  "let's go out together",
#  'Bring me my gun',
#  'Complete the model validation',
#  'move out of my way',
#  'Please clap',
#  'leave the package at the door',
#  'Let us go to the college together Then you can come bo my dorm at night and we can have a good time',
#  'oh behave',
#  'Find documents from May 2017',
#  'Order a new phone',
#  'Please join me for dinner tonight',
#  'Use oil in the pan',
#  'Stop beating the cat',
#  'Sit closer',
#  'And so my fellow Americans ask not what your country can do for you ask what you can do for your country',
#  'Choose wisely my friend',
#  'Show me emails from Tom',
#  'Suprise me',
#  'Write an email to kim saying "This is not a test of the emergency broadcast system "',
#  'stop crying over spilt milk',
#  'say my name again',
#  'do not stall',
#  'Change the lightbulbs',
#  'I need you to sit down now',
#  'have a safe trip',
#  'please be quite in the library',
#  'make sure to pack warm clothes',
#  'pass the salt',
#  "Don't lose control",
#  'Remove all the locks',
#  'Become a better person',
#  "Don't scare me like that",
#  'let him cool down then ask about the incident',
#  'Choose your battles',
#  'Tell us the lies',
#  'Give me the gun',
#  'Tell the truth the whole truth and nothing but the truth',
#  'Wash your shirts',
#  'Paint a big wide smile',
#  "Don't forget to feed the goldfish",
#  'Let me go',
#  'preheat the oven to 325',
#  "Don't lose your way",
#  "Don't forget to change your oil",
#  'Bake a cake',
#  'Come by after dark',
#  'dont take things too seriously',
#  'Launch Edge',
#  'Dont talk',
#  'please join us for breakfast',
#  'Season the cast iron pan',
#  'Do not enter',
#  'Drive slowly',
#  'listen to your teacher',
#  'visit us in the hospital after the baby is born',
#  'Delete all my notifications',
#  'Change regularly',
#  'Never give in Never give in Never never never never in nothing great or small large or petty never give in except to convictions of honor and good sense Never yield to force',
#  'Never yield to the apparently overwhelming might of the enemy',
#  "Turn on the lights so it's not dark",
#  'Find me an expert in postgresql',
#  'Taste the feeling',
#  "Push me away I'll push you away",
#  'Finish your JIRA tasks',
#  'put that down now',
#  'Write a blog post on Google Search',
#  'Tell me a holidy limerick',
#  'Have a good morning',
#  'Come back with their head',
#  'Raise your hand and turn around',
#  'Do your chores',
#  "Heat the house so you don't freeze",
#  'Be careful about what you say',
#  'Save the children',
#  "Don't go anywhere",
#  'Aristotle eleveate the matter',
#  'Compose your atoms with Protons and neutrons',
#  'Keep reading',
#  'Run Forest Run',
#  'Find me an expert in Ruby',
#  'Find me an expert in Python',
#  'Buy me some time',
#  'Find a python developer',
#  'Search for a scala developer',
#  'Spy on all developers',
#  'Launch IE6',
#  'Blind everyone with your smile',
#  'Cremate me when I die',
#  'Wear your coat',
#  'Work on your own',
#  'Give me an easter egg',
#  'Save the date',
#  'Write a blog post on Sentence Type Classification',
#  'Reboot the computer',
#  'Reboot the router',
#  'Reboot the laptop',
#  'Come over after your shift',
#  'Reboot the phone',
#  'Turn off airplane mode',
#  'Turn on the microphone',
#  'Turn on airplane mode',
#  'Turn on bluetooth',
#  'Turn off bluetooth',
#  'Create a new account when if you are hacked',
#  'Turn on wifi',
#  'Watch the fire burn out',
#  'Turn off the wifi',
#  'Shout loud',
#  'Create value or leave',
#  'Walk the line',
#  'Breathe in the smoke',
#  'Pick the nicest thing you can think of',
#  'Walk back to Chicago',
#  'Wake up in the morning',
#  "Don't choke",
#  'Say I love you',
#  'Love me too',
#  'roll over',
#  'Jump on the count of three',
#  'Save the dog if you can',
#  'Bury your dog under the tree',
#  'Add all the files tomorrow',
#  "Don't run from a fight",
#  'Add your comments to the document',
#  'Edit the document adding our comments',
#  'Beam us up',
#  'Chop the carrots',
#  'Join all the comments together',
#  'Come into my home',
#  'Get up stand up Stand up for your rights',
#  "Get up stand up Don't give up the fight",
#  'Join the war effort',
#  'Mix flour and waters',
#  'Break the eggs',
#  'Cook the eggs',
#  'Whisper when you tell me that',
#  'Eat the eggs',
#  'Check the current value before purchasing',
#  'Skip what you can',
#  'Save what you will',
#  'Save all the data',
#  'Swing the golf club harder next time',
#  'Request data',
#  'Request what you can',
#  'Bury the bodies out back',
#  'Skip annoying songs',
#  'Select a winner then rank order the losers',
#  'Raise your hand before you ask a question',
#  'unmute',
#  'unmute the device',
#  'Do what you need to do to survive',
#  'Set phasers to kill',
#  'shut up',
#  'louder',
#  'softer',
#  'speak to me with a british accent',
#  'mute the chat',
#  'mute',
#  'Show me the money',
#  'Fill up my gas tank before you come home',
#  'Slice the steak into small pieces',
#  'open the app',
#  'Show me movie times',
#  'show me the trailer',
#  'ignore other commands',
#  "Add the items to the shopping list so we don't forget next time we go",
#  'increase the volume',
#  'decrease the volume',
#  "Buy a ThankPad it's amazing",
#  'Show mercy to the captives',
#  "Do not do what you shouldn't do",
#  'Show me the TV guide',
#  'set the timer for me',
#  "Don't listen to a word I say",
#  'Cancel the pizza timer',
#  'Stop giving me the creeps',
#  'Set a repeating alarm for weekdays at 9a m',
#  'Please end the call',
#  "Tell everyone goodnight I'll see everyone early tomorrow",
#  'Help me help me',
#  'Somebody help me',
#  'Save me from Alexa',
#  'Send message to Google from alexa',
#  'End my call',
#  "Please don't take the train tonight",
#  'Call Jenny',
#  'Order the bags of fertilzer',
#  'Buy the bags of seed',
#  'Fetch the hardest stick you can find',
#  'Irrigate the fields for me',
#  'Tell the truth',
#  'Plow the lawn if you have time',
#  'Sing a song if you know any',
#  'Hum to the next song you hear',
#  'Update my calendar with the last meeting discussion',
#  'Please check the oven in five minutes',
#  'Drive away without saying goodbye',
#  'Tell me the truth',
#  'Serve your guests some good food else they wont come back',
#  'Remember to wash your sheets',
#  'Open the door for me',
#  'Open up the fridge',
#  'Unlock my phone',
#  'Come to my house when you can',
#  'Come play super smash with me',
#  'Look away',
#  "Come in then Don't stand staring Close that door quick Hustle Don't scrape your feet on the floor Try to look intelligent Don't gape",
#  'Take me back to Switzerland',
#  'Take me to my bedroom',
#  'Make me some Swiss fondue for dinner',
#  'Bake me a cake now',
#  'Come to my party',
#  "Don't eat too much",
#  'Go straight ahead then turn left',
#  'Wake up now',
#  "Don't touch me",
#  "Don't panic",
#  'Get the flag quickly',
#  'Keep off the grass',
#  'Park your car here',
#  'Remove your shoes',
#  'Post those letters',
#  'Pay attention',
#  'Take an asprin',
#  "Don't let your dad know",
#  "Don't let your mom know",
#  'Let us go',
#  "Let's do it",
#  'Let it bleed',
#  'Let it hurt',
#  'Let it heal',
#  'Let it go',
#  'Read the text aloud',
#  'Stand up when you are on the ground',
#  'Drink a beer with me',
#  'Come please',
#  'Come on',
#  "Don't eat so much"]

# %% [markdown]
# # Rule 1

# %%
nlp = en_core_web_lg.load()

# %%
#rule 3: Has a verb in its lemma (base) form and is the root and does not have any subject child in it's dependency structure
def root_verb_in_lemma_nosubj(sent):
    doc = nlp(sent)
    cond1 = False
    cond2 = True
    for token in doc:
        if token.dep_=='ROOT' and token.pos_=='VERB' and token.text.lower() == token.lemma_:
            cond1 = True
            #print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
        if token.dep_ == 'nsubj':
            cond2 = False   
    return (cond1 and cond2)

# %%
## Test for rule 1
rule1 = []
positives_rule1 = []
negatives_rule1 = []

for sentence in imperatives:
    if (root_verb_in_lemma_nosubj(sentence)):
        rule1.append(True)
        positives_rule1.append(sentence)
    else:
        rule1.append(False)
        negatives_rule1.append(sentence)

counter_rule1 = Counter(rule1)
print(counter_rule1)
# Out:
# Counter({True: 508, False: 196})

# %%
negatives_rule1
# Out:
# ['Find out what you like to do most and really give it a whirl',
#  'Lets take a walk',
#  "Don't you talk to me like that",
#  'Let them cool',
#  'Power the world',
#  'Write read do what you need',
#  'Driver carefully',
#  'have a safe trip',
#  'You better be quit',
#  "Give me a few weeks I'll get back to you when I have time",
#  'Be nice to your brother',
#  'be nice',
#  'Be sure to clean your weapon',
#  "speak up I can't hear you",
#  "I'd be grateful if you didn't tell anyone about this",
#  'You watch your mouth young man',
#  'tell her I need her right now',
#  'Make me a cup of tea',
#  'Have a coke and a smile',
#  'Have fun at the fair tonight',
#  'have a break',
#  'Get out of my way',
#  'Save Ferris',
#  'Speak what you think now in hard words and tomorrow speak what tomorrow thinks in hard words again though it contradict every thing you said today',
#  'Sit be quite',
#  'have fun tonight',
#  'Get out',
#  'Take if you must this little bag of dreams',
#  'Report on what you find',
#  'just do it',
#  'Let this generation have theirs',
#  'Be kind for everyone you meet is fighting a hard battle',
#  'Shop without me',
#  'Let the cookies brown before taking them out',
#  'Read every day something no one else is reading Think every day something no one selse is thinking Do every day something no one else would be silly enough to do It is bad for the mind to be always part of the unanimity',
#  'Unloose the cord and they will wrap you round',
#  'Be careful',
#  'tell me what you think',
#  'lets take a walk on the wild side',
#  'Silence',
#  'Shop on sundays',
#  'Silence please',
#  'Swich off your cell phones',
#  'After that add a little milk',
#  'May I suggest the black suit',
#  "Let's face it",
#  'Work in pairs',
#  'tack the package before you leave',
#  'Question everything',
#  'All trading should occur on the Nile',
#  'Fake it or make it',
#  'Have a piece of cake',
#  "Come on Mary I'm waiting",
#  'If this is coffee please bring me some tea but if this is tea please bring me some coffee',
#  'Be a late riser Lazy men are always looking for an easier way be lazy',
#  'Launch Firefox',
#  'Always remember who your boss is',
#  'Roar roar roar Henderson Sungo Do not be afraid Let go of yourself Snarl greatly Feel the lion',
#  'Promise that you will do what you need to do',
#  'March forward',
#  'let them eat cake',
#  'Retreat to England',
#  "Remember what it's worth to you",
#  'Do not condemn the judgement of another because it differs from your own',
#  'Poison the waters supply',
#  'Always play where I can see you',
#  'Touch the great artery Feel it bound like a deer in the might of its lightness and know the thunderless boil of the blood Lean for a bit against this bone It is the only memento you will leave to this earth Its tacitness is everlasting In the hush of the tissue wait with me for the shaft of pronouncement Press your ear against this body the way you did when you were a child holding a seashell and heard faintly the half remembered longed for sea',
#  'Always remember the person who has been nice to you',
#  'do good at school',
#  'Close the door please',
#  'Skip song',
#  'let the rack dry',
#  'when buying cotton to make yourself a nice blouse be sure that it doesnt have gum on it because that way it wont hold up well after a wash soak salt fish overnight before you cook it',
#  'Let the water boil for at least fifteen minutes',
#  "Don't work alone on the assignment it will be much more difficult",
#  'Exercise daily',
#  "don't be late for dinner",
#  'This is mandatory',
#  'Continue to work with the faith that unearned suffering is redemptive',
#  'Boil the turkey in vinegar',
#  'Steep turn go slow',
#  'Open firefox',
#  'Be there at 4am',
#  'Drink is cool with honey',
#  'tell her you did not do it',
#  'keep your friends close but your enemies closer',
#  'Launch Google',
#  'Drive to the roundabout and then turn left',
#  'Work hard play hard',
#  'Get Lost',
#  'Let the dog out for play',
#  "You needn't give me a lift I will go by train",
#  'do not left turn',
#  'do not U turn',
#  'Write an email to austin saying "You\'re the best"',
#  'Crouch under the wall then slide under',
#  "Let the river rock you like a cradle Climb to the treetops child if you're able Let your hands tie a knot across the table",
#  "Come and touch the things you cannot feel And close your fingertips and fly where I can't hold you Let the sun rain fall and let the dewy clouds enfold you And maybe you can sing to me the words I just told you If all the things you feel ain't what they seem And don't mind me 'cause I ain't nothin' but a dream",
#  'Have a safe journey',
#  'Listen before you speak',
#  'Wake me up when suptember ends',
#  'Launch Safari',
#  'Check if the laundry is dry',
#  'Let it occur then arrest them',
#  'May God bless you',
#  'Please go and meet me at the middle of the dance floor after you perform your song',
#  'Fezzik tear his arms off',
#  'Extract the information you can',
#  'Get to bed on time',
#  'Get vaccinated before the age of twelve months',
#  'Write an email to john saying "This is a test email "',
#  'Ask question if you have any',
#  'Do your worst to me',
#  'Turn left at the intersection',
#  'cross the pedestrian lane do not jay walk',
#  'Complete mowing the lawn',
#  'Honk if you like my driving',
#  'Become who you need to be',
#  "let's eat",
#  'be there at five',
#  'Close your eyes when you run away',
#  'Do what I tell you to do',
#  'Tell me whats in your wallet',
#  'Delete as much as you can',
#  'Have a good day',
#  "Shut up Brain or I'll stab you with a Q tip",
#  'tell me what you think',
#  'be kind to your neighbors',
#  'Come over here let me show you',
#  "let's go out together",
#  'Let us go to the college together Then you can come bo my dorm at night and we can have a good time',
#  'And so my fellow Americans ask not what your country can do for you ask what you can do for your country',
#  'Write an email to kim saying "This is not a test of the emergency broadcast system "',
#  'I need you to sit down now',
#  'have a safe trip',
#  'please be quite in the library',
#  'let him cool down then ask about the incident',
#  'Let me go',
#  'Launch Edge',
#  'Season the cast iron pan',
#  'Drive slowly',
#  'Change regularly',
#  "Turn on the lights so it's not dark",
#  "Push me away I'll push you away",
#  'Have a good morning',
#  'Do your chores',
#  "Heat the house so you don't freeze",
#  'Be careful about what you say',
#  'Aristotle eleveate the matter',
#  'Run Forest Run',
#  'Search for a scala developer',
#  'Spy on all developers',
#  'Blind everyone with your smile',
#  'Cremate me when I die',
#  'Watch the fire burn out',
#  'Pick the nicest thing you can think of',
#  'Say I love you',
#  'Save the dog if you can',
#  'Get up stand up Stand up for your rights',
#  'Whisper when you tell me that',
#  'Save what you will',
#  'Request data',
#  'Request what you can',
#  'Raise your hand before you ask a question',
#  'Do what you need to do to survive',
#  'louder',
#  'softer',
#  'mute',
#  'Fill up my gas tank before you come home',
#  "Add the items to the shopping list so we don't forget next time we go",
#  "Buy a ThankPad it's amazing",
#  "Do not do what you shouldn't do",
#  "Don't listen to a word I say",
#  "Tell everyone goodnight I'll see everyone early tomorrow",
#  'Help me help me',
#  'Somebody help me',
#  'Call Jenny',
#  'Fetch the hardest stick you can find',
#  'Plow the lawn if you have time',
#  'Sing a song if you know any',
#  'Hum to the next song you hear',
#  'Serve your guests some good food else they wont come back',
#  'Come to my house when you can',
#  "Come in then Don't stand staring Close that door quick Hustle Don't scrape your feet on the floor Try to look intelligent Don't gape",
#  'Make me some Swiss fondue for dinner',
#  'Go straight ahead then turn left',
#  'Get the flag quickly',
#  "Don't let your dad know",
#  "Don't let your mom know",
#  'Let us go',
#  "Let's do it",
#  'Let it bleed',
#  'Let it hurt',
#  'Let it heal',
#  'Let it go',
#  'Stand up when you are on the ground']

# %% [markdown]
# # Rule 2

# %%
# Define the keywords that will be used to extract the imperative sentences
# Rules are identified from the paper - https://www.aclweb.org/anthology/W14-2117.pdf
# 1. "find those sentences with a verb (in its base form) as the root 
#     in the phrase structure and this particular verb has no 
#.    subject child in the dependency structure" 
#.    Example: You must first discuss the matter there, and you need to be specific”
# 2. "recognize the use of a personal pronoun or noun (e.g., “you”, “we”,
#.     or a username) followed by a modal verb (e.g., “should”, “must”, “need”) as an imperative"


# Source: https://www.myenglishpages.com/site_php_files/grammar-lesson-modals.php
modal_verbs = ['can', 'cant','could', 'couldnt', 'may', 'might', 'will', 'wont', 'would', 'wouldnt', 'shall','should', \
               'shouldnt', 'must', 'ought', 'dare', 'had better', 'ask']
# modal_verbs = ['can', 'may', 'might', 'will', 'would', 'shall','should', 'must', 'ought', 'dare', 'had better', 'ask']

# Source: https://grammar.yourdictionary.com/parts-of-speech/pronouns/list-of-personal-pronouns.html
# personal_pronoun = ['I', 'me', 'we', 'us', 'you', 'he', 'she', 'her', 'him', 'it', 'they', 'them']
personal_pronoun = ['us', 'you', 'he', 'she', 'her', 'him', 'it', 'they', 'them']

# %%
# Check for rule 2

# Create combinations of possibilities for a sentence to be imperative
combinations = []
# form combinations of words and put them as a list
for pronoun in personal_pronoun:
    for verb in modal_verbs:
        combinations.append(pronoun + ' ' + verb)
        
print('Number of combinations for rule 2 =', len(combinations))
# Out:
# Number of combinations for rule 2 = 162

# %%
# Using rule 2 to check imperative snetences
def check_imperative_r2(combinations, sentence):
    if any(combo in sentence.lower() for combo in combinations):
        return True
    return False

# %%
## Test for rule 2
rule2 = []
positives_rule2 = []
negatives_rule2 = []

for sentence in imperatives:
    if (check_imperative_r2(combinations, sentence)):
        rule2.append(True)
        positives_rule2.append(sentence)
    else:
        rule2.append(False)
        negatives_rule2.append(sentence)

counter_rule2 = Counter(rule2)
print(counter_rule2)
# Out:
# Counter({False: 683, True: 21})

# %%
negatives_rule2
# Out:
# ['Remember the test date',
#  'Live in peace',
#  'Include the required attachement s',
#  "Don't follow me",
#  'Do not eat in class',
#  'Kill the butterfly',
#  'Take me to the library',
#  'Find out what you like to do most and really give it a whirl',
#  'Believe me',
#  'Move around town',
#  'Lets take a walk',
#  'Dont stop me now',
#  'Stop talking now',
#  'Do not smoke in your room',
#  "Don't you talk to me like that",
#  "Don't worry be happy",
#  'Eat your veggies',
#  'Let them cool',
#  'Take your coat off',
#  'Power the world',
#  'Stop and Go',
#  'repair your camera',
#  'Write read do what you need',
#  'Dont touch me',
#  'Mix together sugar and salt',
#  'Lock the door',
#  'Rise against the tyrannical government',
#  'Make up your mind to pool your resources and get the moust out of your remaining years of life',
#  'Driver carefully',
#  'have a safe trip',
#  'bring me a suitcase from my closet',
#  "Don't wait for my answer get started right away",
#  'give me your full name please',
#  'You better be quit',
#  'Eat them with milk',
#  'meet me at the town square',
#  'buy now while supplies last',
#  'Run for cover',
#  'Buy a dog',
#  'Enjoy some fresh apples',
#  'Pass through the intersection and take a right in 2 miles',
#  'Start a fire with your bare hands',
#  'change your clothes after playing outside',
#  'Write an email to your boss',
#  'Learn your lessons',
#  'Mop the floor',
#  'Play ball',
#  'Give us the gate key',
#  "Give me a few weeks I'll get back to you when I have time",
#  'Cancel the meeting',
#  'Be nice to your brother',
#  'Open the window',
#  'Keep working',
#  'be nice',
#  'Believe me',
#  'Wait for it',
#  'Write in Irish',
#  'Stand in line',
#  'Live in balance with nature',
#  'Speak freely and spread the word',
#  'Be sure to clean your weapon',
#  'Return the slaves',
#  "speak up I can't hear you",
#  "I'd be grateful if you didn't tell anyone about this",
#  'You watch your mouth young man',
#  'tell her I need her right now',
#  'Make me a cup of tea',
#  'Have a coke and a smile',
#  "Don't go out on the ice",
#  'buy now while supplies last',
#  'Have fun at the fair tonight',
#  'have a break',
#  'Buy a kitkat',
#  'Get out of my way',
#  'stop playing with your food',
#  'Save Ferris',
#  'Lead the pack',
#  'Speak what you think now in hard words and tomorrow speak what tomorrow thinks in hard words again though it contradict every thing you said today',
#  'please lower your voice',
#  'Cancel the order',
#  'Help the poor',
#  'First boil some water',
#  'pass the bowl of potatoes',
#  'Sit be quite',
#  'Feed the hungry',
#  'have fun tonight',
#  'put the cake out to cool',
#  'Get out',
#  'Please be quit',
#  'Report on what you find',
#  'love your enemies',
#  'Work to achive the goals',
#  'just do it',
#  'Let this generation have theirs',
#  'buy one and save 50 on your next purchase',
#  'Enjoy your meal',
#  'Be kind for everyone you meet is fighting a hard battle',
#  'Shop without me',
#  'Carry by hand gun',
#  "Don't eat my grapes",
#  'feel free to text me later',
#  'Speak in spanish',
#  'Heat the pan with oil',
#  'Take notes while listening',
#  'choose the German Sheperd over the huskey',
#  'please find my yellow leotard',
#  "Don't press that button",
#  'Launch the missles',
#  'Then pour the water into a cup',
#  'Cut out the cookies with a cookie cutter',
#  "Don't eat the cookies",
#  'Remember to wash under your armpits',
#  'Let the cookies brown before taking them out',
#  'call the doctor',
#  'Take me home',
#  'Enrich the poor',
#  'consider the red dress',
#  'Watch the videos and report back',
#  'Dont take things too seriously',
#  'come with me',
#  'Read every day something no one else is reading Think every day something no one selse is thinking Do every day something no one else would be silly enough to do It is bad for the mind to be always part of the unanimity',
#  'Put down the spoon',
#  'Be careful',
#  'Wait for me',
#  'tell me what you think',
#  'lets take a walk on the wild side',
#  'Paint the door',
#  'Look for the painted lady',
#  'Cure the sick',
#  'Silence',
#  'Throw the ball',
#  'Shop on sundays',
#  'Silence please',
#  'Dream big',
#  'Swich off your cell phones',
#  'Turn off your phones',
#  'Remove any batteries from your luggage',
#  'Dont text me',
#  "Don't beat him",
#  'do not kill',
#  'Do not waste your time',
#  'After that add a little milk',
#  'May I suggest the black suit',
#  'Put down the knife',
#  'Go to the edge of the cliff and jump off Build your own wings on the way down',
#  'Eat logs of popcorn',
#  'black me out',
#  'Play the guitar for me',
#  'Stand up',
#  "Let's face it",
#  'Do take a seat',
#  'please hand me the keys',
#  'Work in pairs',
#  'Please tidy up your room',
#  'Fetch a glass of water',
#  'Complete the exercies',
#  'tack the package before you leave',
#  'Slice the apple',
#  'open the back door',
#  'Question everything',
#  'join our table during the wedding',
#  'play nice in the sandbox',
#  'Roll out your cookie dough',
#  "Don't forget to take your passport with you",
#  'Forget all about it',
#  'Dont steal the cookies from the cookie jar',
#  'please send the nurse in',
#  'Tell me the story of your life',
#  'Stir in the coffee',
#  'do not bear false witness against thy neighbor',
#  'pay me',
#  "Don't stay out too late",
#  'Switch off the AC',
#  'Listen to the audio',
#  'Keep your cell phones or laptops closed',
#  'Move out of the way',
#  'Try to skip the first step',
#  'Please join my wife and I for dinner',
#  'All trading should occur on the Nile',
#  'Fake it or make it',
#  'Clean the desk',
#  'Have a piece of cake',
#  'Move quickly',
#  'Run fast',
#  'Write a letter to the warden',
#  "Come on Mary I'm waiting",
#  'come and celebrate the festivies before the night of the dance with me',
#  'come to the ball with me',
#  'do not turn left on red',
#  'play the song Mercy Me by Alkaline Trio',
#  'Wash the white clothes on Monday and put them on the stone heap wash the color clothes on Tuesday and put them on the clothesline to dry dont walk barehead in the hot sun',
#  'If this is coffee please bring me some tea but if this is tea please bring me some coffee',
#  'Go up to the board',
#  'Be a late riser Lazy men are always looking for an easier way be lazy',
#  'Dont forget me',
#  'Launch Firefox',
#  'Relax',
#  'complete these by tomorrow',
#  'Always remember who your boss is',
#  'come with me to church',
#  'Continue to deliver on your obligations',
#  'Play me a tune from your trumpet',
#  'Do not make a noise',
#  'Take your medicines',
#  'Fetch me a glass of water',
#  'Write your name on the exam',
#  'Pause the song',
#  'Dont look back',
#  'hurry',
#  'Hurry up',
#  'Roar roar roar Henderson Sungo Do not be afraid Let go of yourself Snarl greatly Feel the lion',
#  'Eat the lunch full',
#  'Wash your hands before eating',
#  'Stop the bus',
#  'Help me',
#  'Do not miss your class',
#  'Finish your task',
#  'March forward',
#  'Do not eat in class',
#  'Walk to the corner turn left and cross the road',
#  'Try again next time',
#  'Complete these files by tomorrow',
#  'Write a text to your wife',
#  'let them eat cake',
#  'Use this website',
#  'Retreat to England',
#  'shut the door',
#  "Remember what it's worth to you",
#  'Turn around in 300 meters',
#  'Play the song alive by ima robot',
#  'Do not condemn the judgement of another because it differs from your own',
#  'Play hard work hard',
#  'Stay alive and avoid zombies',
#  'Come out with us tonight',
#  "Don't ever speak to me like that again",
#  'Poison the waters supply',
#  'Always play where I can see you',
#  'Change the dirty diapers',
#  'Always remember the person who has been nice to you',
#  'do good at school',
#  'Promise me',
#  'Close the door please',
#  'Fold the blanket',
#  'stop',
#  'Raid the Berber people',
#  'Make chocolate chip cookies for christmas',
#  'halt',
#  'turn right on red',
#  'honor your father and your mother',
#  'Hand over the assignment',
#  'Set the temperature 1 degree higher',
#  'Meet me outside the venue',
#  'Switch on the fan please',
#  'Write your personal manifesto',
#  'Enjoy life',
#  'Skip song',
#  'Note it down',
#  'Respect the elders',
#  'Turn on the radio',
#  'Look away',
#  'let the rack dry',
#  'Play the song test',
#  'Please go on reading',
#  'Let the water boil for at least fifteen minutes',
#  'Watch your step',
#  'Do Exercise daily',
#  'Exercise daily',
#  'Redo the translation',
#  'Assist in the discovery',
#  'Flip the table',
#  'Consider the lily',
#  'Invade france from the north',
#  'stop eating too much',
#  "Don't tease him",
#  "don't be late for dinner",
#  'This is mandatory',
#  'Set the temperature to 80',
#  'Swing wide',
#  'Check your email',
#  'Work Hard',
#  'Continue to work with the faith that unearned suffering is redemptive',
#  'Boil the turkey in vinegar',
#  "Don't Drink",
#  'Steep turn go slow',
#  'Open firefox',
#  'Shoot straight',
#  'Run faster',
#  'Turn off the radio',
#  'Clean the bathrooms',
#  'Meet back here after shopping',
#  'Be there at 4am',
#  'Drink is cool with honey',
#  'Skip this song',
#  'call me after 10am',
#  'Redo all the work',
#  'Call me maybe',
#  'Play the song "test"',
#  'Take a note',
#  'Keep hanky in pocket',
#  'Go back to Mississippi',
#  'stop',
#  'tell her you did not do it',
#  'Listen closely my friends',
#  'Never speak to me like that again',
#  'Help in the arrest',
#  'Drink a bourbon',
#  'Load your weapon',
#  'Please close the door',
#  'Wake me up on the weekend',
#  'Study hard for the math exam',
#  'Turn right in 500 feet',
#  'keep your friends close but your enemies closer',
#  'Launch Google',
#  'Drive to the roundabout and then turn left',
#  'Stop that',
#  'Collect nice books',
#  'Work hard play hard',
#  'Apply the glue thinly and leave it for ten minutes',
#  'Get Lost',
#  'Keep an eye on the time',
#  'Leave the class',
#  'Switch off the lights',
#  'Pass the book please',
#  'Please grill the sandwich',
#  'Maintain silence',
#  'Stay ahead',
#  "Don't let the lights get turned on",
#  'Let the dog out for play',
#  'Reach for the sky',
#  'Stop the track',
#  'Slap the naughty boy',
#  "You needn't give me a lift I will go by train",
#  'Overhaul the passages',
#  'do not left turn',
#  'Remember the Sabbath day by keeping it holy',
#  "Don't think about the future",
#  'Stop feeding the lions',
#  'Drink a port',
#  'Fill in the blanks',
#  'do not U turn',
#  'Turn right in 200 feet',
#  'Write an email to austin saying "You\'re the best"',
#  'Crouch under the wall then slide under',
#  'complete a u turn',
#  "Let the river rock you like a cradle Climb to the treetops child if you're able Let your hands tie a knot across the table",
#  'Have a safe journey',
#  'Iron the shirt',
#  'Call me tomorrow',
#  'Listen before you speak',
#  'Do not come home late',
#  'Wear your gold necklace with that dress',
#  'Remind me in 10 days to email Austin',
#  'Swing hard johnny',
#  'Find the document titled "test"',
#  'Wake me up when suptember ends',
#  'Summarize the news for me',
#  'Smile for the camera',
#  'Complete the photo shoot',
#  'Launch Safari',
#  'go',
#  'Check if the laundry is dry',
#  'Fold your laundry',
#  'Let it occur then arrest them',
#  'walk for the minimum',
#  'clean the sidewalk',
#  'Call your parents on sunday',
#  'Discover the fall of the Roman Empire',
#  'go back to Alabama',
#  'May God bless you',
#  'Cook the steak well done',
#  'Please go and meet me at the middle of the dance floor after you perform your song',
#  'Turn on the kitchen light',
#  'talk to the hand',
#  'Stop feeding the dog from the table',
#  'Come around and see me some time',
#  'Save our Souls',
#  'Hit the ball',
#  'Use the big red nipple to move around',
#  'Complete all your work or else',
#  'Please leave',
#  'Fezzik tear his arms off',
#  'Get to bed on time',
#  'Work fast',
#  'Run fast',
#  'Skip to the next track',
#  'Find the document called "google"',
#  'Sleep well',
#  'Throw the ball',
#  'Get vaccinated before the age of twelve months',
#  'stir toegether flour baking soda and baking powder',
#  'Talk to me about dan',
#  'Take a taxi',
#  'Write an email to john saying "This is a test email "',
#  'Ask question if you have any',
#  'Eat something',
#  'Do your worst to me',
#  'Drink lots of water',
#  'Bring that to me',
#  'Find the lost treasure',
#  'go back to South Carolina go back to Georgia',
#  'Give me a new TV',
#  'Turn left at the intersection',
#  'Do not honk',
#  'Show me emails from Austin',
#  'Do not make the naughty list',
#  'Turn off the living room lights',
#  'cross the pedestrian lane do not jay walk',
#  'Complete mowing the lawn',
#  'Crack the game',
#  'sit in a semicircle',
#  'Clap',
#  'Put your hand into the bag',
#  'break a leg',
#  'Tell me about the weather',
#  "Don't eat all the cookies",
#  'Keep Calm and Carry On',
#  'Honk if you like my driving',
#  'stop yelling',
#  'run',
#  'Become who you need to be',
#  'Please tidy your room',
#  "let's eat",
#  'run for your life',
#  'go back to Louisiana',
#  'Find documents from June 1st on',
#  'pour me a glass of bourbon',
#  'Play me a short clip',
#  'Improve yourself or kiss yourself goodbye',
#  'be there at five',
#  'Roll the dice',
#  'Go to bed early',
#  'Close your eyes when you run away',
#  'Leave me here alone to collect my things',
#  'Eat your popcorn',
#  'Lend me a dollar',
#  'Please open the door would you',
#  'Crack your iphone',
#  "Don't trouble the children",
#  'shut the front door',
#  'Complete your work on sunday',
#  'Clear this room by tomorrow morning',
#  'Turn the record over',
#  'Pack enough food for our adventure',
#  'Ask for more work when you are done',
#  'Do what I tell you to do',
#  'Tell me whats in your wallet',
#  'go back to the slums and ghettos of our northern cities knowing that somehow this situation can and will be changed',
#  'Give me a Robert Heinlein quot',
#  'Find the remote',
#  "Don't feed the dog",
#  'Have a good day',
#  "Shut up Brain or I'll stab you with a Q tip",
#  'tell me what you think',
#  'please join me at the after party',
#  'be kind to your neighbors',
#  'Plant enough trees for the summer',
#  'Come over here let me show you',
#  "let's go out together",
#  'Bring me my gun',
#  'Complete the model validation',
#  'move out of my way',
#  'Please clap',
#  'leave the package at the door',
#  'oh behave',
#  'Find documents from May 2017',
#  'Order a new phone',
#  'Please join me for dinner tonight',
#  'Use oil in the pan',
#  'Stop beating the cat',
#  'Sit closer',
#  'Choose wisely my friend',
#  'Show me emails from Tom',
#  'Suprise me',
#  'Write an email to kim saying "This is not a test of the emergency broadcast system "',
#  'stop crying over spilt milk',
#  'say my name again',
#  'do not stall',
#  'Change the lightbulbs',
#  'I need you to sit down now',
#  'have a safe trip',
#  'please be quite in the library',
#  'make sure to pack warm clothes',
#  'pass the salt',
#  "Don't lose control",
#  'Remove all the locks',
#  'Become a better person',
#  "Don't scare me like that",
#  'let him cool down then ask about the incident',
#  'Choose your battles',
#  'Tell us the lies',
#  'Give me the gun',
#  'Tell the truth the whole truth and nothing but the truth',
#  'Wash your shirts',
#  'Paint a big wide smile',
#  "Don't forget to feed the goldfish",
#  'Let me go',
#  'preheat the oven to 325',
#  "Don't lose your way",
#  "Don't forget to change your oil",
#  'Bake a cake',
#  'Come by after dark',
#  'dont take things too seriously',
#  'Launch Edge',
#  'Dont talk',
#  'please join us for breakfast',
#  'Season the cast iron pan',
#  'Do not enter',
#  'Drive slowly',
#  'listen to your teacher',
#  'visit us in the hospital after the baby is born',
#  'Delete all my notifications',
#  'Change regularly',
#  'Never give in Never give in Never never never never in nothing great or small large or petty never give in except to convictions of honor and good sense Never yield to force',
#  'Never yield to the apparently overwhelming might of the enemy',
#  "Turn on the lights so it's not dark",
#  'Find me an expert in postgresql',
#  'Taste the feeling',
#  "Push me away I'll push you away",
#  'Finish your JIRA tasks',
#  'put that down now',
#  'Write a blog post on Google Search',
#  'Tell me a holidy limerick',
#  'Have a good morning',
#  'Come back with their head',
#  'Raise your hand and turn around',
#  'Do your chores',
#  "Heat the house so you don't freeze",
#  'Be careful about what you say',
#  'Save the children',
#  "Don't go anywhere",
#  'Aristotle eleveate the matter',
#  'Compose your atoms with Protons and neutrons',
#  'Keep reading',
#  'Run Forest Run',
#  'Find me an expert in Ruby',
#  'Find me an expert in Python',
#  'Buy me some time',
#  'Find a python developer',
#  'Search for a scala developer',
#  'Spy on all developers',
#  'Launch IE6',
#  'Blind everyone with your smile',
#  'Cremate me when I die',
#  'Wear your coat',
#  'Work on your own',
#  'Give me an easter egg',
#  'Save the date',
#  'Write a blog post on Sentence Type Classification',
#  'Reboot the computer',
#  'Reboot the router',
#  'Reboot the laptop',
#  'Come over after your shift',
#  'Reboot the phone',
#  'Turn off airplane mode',
#  'Turn on the microphone',
#  'Turn on airplane mode',
#  'Turn on bluetooth',
#  'Turn off bluetooth',
#  'Create a new account when if you are hacked',
#  'Turn on wifi',
#  'Watch the fire burn out',
#  'Turn off the wifi',
#  'Shout loud',
#  'Create value or leave',
#  'Walk the line',
#  'Breathe in the smoke',
#  'Walk back to Chicago',
#  'Wake up in the morning',
#  "Don't choke",
#  'Say I love you',
#  'Love me too',
#  'roll over',
#  'Jump on the count of three',
#  'Bury your dog under the tree',
#  'Add all the files tomorrow',
#  "Don't run from a fight",
#  'Add your comments to the document',
#  'Edit the document adding our comments',
#  'Beam us up',
#  'Chop the carrots',
#  'Join all the comments together',
#  'Come into my home',
#  'Get up stand up Stand up for your rights',
#  "Get up stand up Don't give up the fight",
#  'Join the war effort',
#  'Mix flour and waters',
#  'Break the eggs',
#  'Cook the eggs',
#  'Whisper when you tell me that',
#  'Eat the eggs',
#  'Check the current value before purchasing',
#  'Save all the data',
#  'Swing the golf club harder next time',
#  'Request data',
#  'Bury the bodies out back',
#  'Skip annoying songs',
#  'Select a winner then rank order the losers',
#  'unmute',
#  'unmute the device',
#  'Do what you need to do to survive',
#  'Set phasers to kill',
#  'shut up',
#  'louder',
#  'softer',
#  'speak to me with a british accent',
#  'mute the chat',
#  'mute',
#  'Show me the money',
#  'Fill up my gas tank before you come home',
#  'Slice the steak into small pieces',
#  'open the app',
#  'Show me movie times',
#  'show me the trailer',
#  'ignore other commands',
#  "Add the items to the shopping list so we don't forget next time we go",
#  'increase the volume',
#  'decrease the volume',
#  "Buy a ThankPad it's amazing",
#  'Show mercy to the captives',
#  'Show me the TV guide',
#  'set the timer for me',
#  "Don't listen to a word I say",
#  'Cancel the pizza timer',
#  'Stop giving me the creeps',
#  'Set a repeating alarm for weekdays at 9a m',
#  'Please end the call',
#  "Tell everyone goodnight I'll see everyone early tomorrow",
#  'Help me help me',
#  'Somebody help me',
#  'Save me from Alexa',
#  'Send message to Google from alexa',
#  'End my call',
#  "Please don't take the train tonight",
#  'Call Jenny',
#  'Order the bags of fertilzer',
#  'Buy the bags of seed',
#  'Irrigate the fields for me',
#  'Tell the truth',
#  'Plow the lawn if you have time',
#  'Sing a song if you know any',
#  'Hum to the next song you hear',
#  'Update my calendar with the last meeting discussion',
#  'Please check the oven in five minutes',
#  'Drive away without saying goodbye',
#  'Tell me the truth',
#  'Remember to wash your sheets',
#  'Open the door for me',
#  'Open up the fridge',
#  'Unlock my phone',
#  'Come play super smash with me',
#  'Look away',
#  "Come in then Don't stand staring Close that door quick Hustle Don't scrape your feet on the floor Try to look intelligent Don't gape",
#  'Take me back to Switzerland',
#  'Take me to my bedroom',
#  'Make me some Swiss fondue for dinner',
#  'Bake me a cake now',
#  'Come to my party',
#  "Don't eat too much",
#  'Go straight ahead then turn left',
#  'Wake up now',
#  "Don't touch me",
#  "Don't panic",
#  'Get the flag quickly',
#  'Keep off the grass',
#  'Park your car here',
#  'Remove your shoes',
#  'Post those letters',
#  'Pay attention',
#  'Take an asprin',
#  "Don't let your dad know",
#  "Don't let your mom know",
#  'Let us go',
#  "Let's do it",
#  'Let it bleed',
#  'Let it hurt',
#  'Let it heal',
#  'Let it go',
#  'Read the text aloud',
#  'Stand up when you are on the ground',
#  'Drink a beer with me',
#  'Come please',
#  'Come on',
#  "Don't eat so much"]

# %% [markdown]
# ## Find the statements that were different

# %%
identified_by_rule1_only = np.setdiff1d(positives_rule2, positives_rule1, assume_unique=True).tolist()
print('Identified by rule 1 but not by rule 2', len(identified_by_rule1_only))

for sent in identified_by_rule1_only:
    print(sent)
# Out:
# Identified by rule 1 but not by rule 2 20
# Take if you must this little bag of dreams
# Unloose the cord and they will wrap you round
# Promise that you will do what you need to do
# Touch the great artery Feel it bound like a deer in the might of its lightness and know the thunderless boil of the blood Lean for a bit against this bone It is the only memento you will leave to this earth Its tacitness is everlasting In the hush of the tissue wait with me for the shaft of pronouncement Press your ear against this body the way you did when you were a child holding a seashell and heard faintly the half remembered longed for sea
# when buying cotton to make yourself a nice blouse be sure that it doesnt have gum on it because that way it wont hold up well after a wash soak salt fish overnight before you cook it
# Don't work alone on the assignment it will be much more difficult
# Come and touch the things you cannot feel And close your fingertips and fly where I can't hold you Let the sun rain fall and let the dewy clouds enfold you And maybe you can sing to me the words I just told you If all the things you feel ain't what they seem And don't mind me 'cause I ain't nothin' but a dream
# Extract the information you can
# Delete as much as you can
# Let us go to the college together Then you can come bo my dorm at night and we can have a good time
# And so my fellow Americans ask not what your country can do for you ask what you can do for your country
# Pick the nicest thing you can think of
# Save the dog if you can
# Save what you will
# Request what you can
# Raise your hand before you ask a question
# Do not do what you shouldn't do
# Fetch the hardest stick you can find
# Serve your guests some good food else they wont come back
# Come to my house when you can

# %%
len(identified_by_rule1_only)
# Out:
# 20

# %%
all_posiitve = positives_rule1.extend(positives_rule2)
missed_by_rules = np.setdiff1d(imperatives, all_posiitve, assume_unique=True).tolist()

print(len(missed_by_rules))

for sent in missed_by_rules:
    print(sent)
# Out:
# 704
# Remember the test date
# Live in peace
# Include the required attachement s
# Don't follow me
# Do not eat in class
# Kill the butterfly
# Take me to the library
# Find out what you like to do most and really give it a whirl
# Believe me
# Move around town
# Lets take a walk
# Dont stop me now
# Stop talking now
# Do not smoke in your room
# Don't you talk to me like that
# Don't worry be happy
# Eat your veggies
# Let them cool
# Take your coat off
# Power the world
# Stop and Go
# repair your camera
# Write read do what you need
# Dont touch me
# Mix together sugar and salt
# Lock the door
# Rise against the tyrannical government
# Make up your mind to pool your resources and get the moust out of your remaining years of life
# Driver carefully
# have a safe trip
# bring me a suitcase from my closet
# Don't wait for my answer get started right away
# give me your full name please
# You better be quit
# Eat them with milk
# meet me at the town square
# buy now while supplies last
# Run for cover
# Buy a dog
# Enjoy some fresh apples
# Pass through the intersection and take a right in 2 miles
# Start a fire with your bare hands
# change your clothes after playing outside
# Write an email to your boss
# Learn your lessons
# Mop the floor
# Play ball
# Give us the gate key
# Give me a few weeks I'll get back to you when I have time
# Cancel the meeting
# Be nice to your brother
# Open the window
# Keep working
# be nice
# Believe me
# Wait for it
# Write in Irish
# Stand in line
# Live in balance with nature
# Speak freely and spread the word
# Be sure to clean your weapon
# Return the slaves
# speak up I can't hear you
# I'd be grateful if you didn't tell anyone about this
# You watch your mouth young man
# tell her I need her right now
# Make me a cup of tea
# Have a coke and a smile
# Don't go out on the ice
# buy now while supplies last
# Have fun at the fair tonight
# have a break
# Buy a kitkat
# Get out of my way
# stop playing with your food
# Save Ferris
# Lead the pack
# Speak what you think now in hard words and tomorrow speak what tomorrow thinks in hard words again though it contradict every thing you said today
# please lower your voice
# Cancel the order
# Help the poor
# First boil some water
# pass the bowl of potatoes
# Sit be quite
# Feed the hungry
# have fun tonight
# put the cake out to cool
# Get out
# Please be quit
# Take if you must this little bag of dreams
# Report on what you find
# love your enemies
# Work to achive the goals
# just do it
# Let this generation have theirs
# buy one and save 50 on your next purchase
# Enjoy your meal
# Be kind for everyone you meet is fighting a hard battle
# Shop without me
# Carry by hand gun
# Don't eat my grapes
# feel free to text me later
# Speak in spanish
# Heat the pan with oil
# Take notes while listening
# choose the German Sheperd over the huskey
# please find my yellow leotard
# Don't press that button
# Launch the missles
# Then pour the water into a cup
# Cut out the cookies with a cookie cutter
# Don't eat the cookies
# Remember to wash under your armpits
# Let the cookies brown before taking them out
# call the doctor
# Take me home
# Enrich the poor
# consider the red dress
# Watch the videos and report back
# Dont take things too seriously
# come with me
# Read every day something no one else is reading Think every day something no one selse is thinking Do every day something no one else would be silly enough to do It is bad for the mind to be always part of the unanimity
# Unloose the cord and they will wrap you round
# Put down the spoon
# Be careful
# Wait for me
# tell me what you think
# lets take a walk on the wild side
# Paint the door
# Look for the painted lady
# Cure the sick
# Silence
# Throw the ball
# Shop on sundays
# Silence please
# Dream big
# Swich off your cell phones
# Turn off your phones
# Remove any batteries from your luggage
# Dont text me
# Don't beat him
# do not kill
# Do not waste your time
# After that add a little milk
# May I suggest the black suit
# Put down the knife
# Go to the edge of the cliff and jump off Build your own wings on the way down
# Eat logs of popcorn
# black me out
# Play the guitar for me
# Stand up
# Let's face it
# Do take a seat
# please hand me the keys
# Work in pairs
# Please tidy up your room
# Fetch a glass of water
# Complete the exercies
# tack the package before you leave
# Slice the apple
# open the back door
# Question everything
# join our table during the wedding
# play nice in the sandbox
# Roll out your cookie dough
# Don't forget to take your passport with you
# Forget all about it
# Dont steal the cookies from the cookie jar
# please send the nurse in
# Tell me the story of your life
# Stir in the coffee
# do not bear false witness against thy neighbor
# pay me
# Don't stay out too late
# Switch off the AC
# Listen to the audio
# Keep your cell phones or laptops closed
# Move out of the way
# Try to skip the first step
# Please join my wife and I for dinner
# All trading should occur on the Nile
# Fake it or make it
# Clean the desk
# Have a piece of cake
# Move quickly
# Run fast
# Write a letter to the warden
# Come on Mary I'm waiting
# come and celebrate the festivies before the night of the dance with me
# come to the ball with me
# do not turn left on red
# play the song Mercy Me by Alkaline Trio
# Wash the white clothes on Monday and put them on the stone heap wash the color clothes on Tuesday and put them on the clothesline to dry dont walk barehead in the hot sun
# If this is coffee please bring me some tea but if this is tea please bring me some coffee
# Go up to the board
# Be a late riser Lazy men are always looking for an easier way be lazy
# Dont forget me
# Launch Firefox
# Relax
# complete these by tomorrow
# Always remember who your boss is
# come with me to church
# Continue to deliver on your obligations
# Play me a tune from your trumpet
# Do not make a noise
# Take your medicines
# Fetch me a glass of water
# Write your name on the exam
# Pause the song
# Dont look back
# hurry
# Hurry up
# Roar roar roar Henderson Sungo Do not be afraid Let go of yourself Snarl greatly Feel the lion
# Eat the lunch full
# Wash your hands before eating
# Stop the bus
# Help me
# Do not miss your class
# Finish your task
# Promise that you will do what you need to do
# March forward
# Do not eat in class
# Walk to the corner turn left and cross the road
# Try again next time
# Complete these files by tomorrow
# Write a text to your wife
# let them eat cake
# Use this website
# Retreat to England
# shut the door
# Remember what it's worth to you
# Turn around in 300 meters
# Play the song alive by ima robot
# Do not condemn the judgement of another because it differs from your own
# Play hard work hard
# Stay alive and avoid zombies
# Come out with us tonight
# Don't ever speak to me like that again
# Poison the waters supply
# Always play where I can see you
# Change the dirty diapers
# Touch the great artery Feel it bound like a deer in the might of its lightness and know the thunderless boil of the blood Lean for a bit against this bone It is the only memento you will leave to this earth Its tacitness is everlasting In the hush of the tissue wait with me for the shaft of pronouncement Press your ear against this body the way you did when you were a child holding a seashell and heard faintly the half remembered longed for sea
# Always remember the person who has been nice to you
# do good at school
# Promise me
# Close the door please
# Fold the blanket
# stop
# Raid the Berber people
# Make chocolate chip cookies for christmas
# halt
# turn right on red
# honor your father and your mother
# Hand over the assignment
# Set the temperature 1 degree higher
# Meet me outside the venue
# Switch on the fan please
# Write your personal manifesto
# Enjoy life
# Skip song
# Note it down
# Respect the elders
# Turn on the radio
# Look away
# let the rack dry
# when buying cotton to make yourself a nice blouse be sure that it doesnt have gum on it because that way it wont hold up well after a wash soak salt fish overnight before you cook it
# Play the song test
# Please go on reading
# Let the water boil for at least fifteen minutes
# Watch your step
# Don't work alone on the assignment it will be much more difficult
# Do Exercise daily
# Exercise daily
# Redo the translation
# Assist in the discovery
# Flip the table
# Consider the lily
# Invade france from the north
# stop eating too much
# Don't tease him
# don't be late for dinner
# This is mandatory
# Set the temperature to 80
# Swing wide
# Check your email
# Work Hard
# Continue to work with the faith that unearned suffering is redemptive
# Boil the turkey in vinegar
# Don't Drink
# Steep turn go slow
# Open firefox
# Shoot straight
# Run faster
# Turn off the radio
# Clean the bathrooms
# Meet back here after shopping
# Be there at 4am
# Drink is cool with honey
# Skip this song
# call me after 10am
# Redo all the work
# Call me maybe
# Play the song "test"
# Take a note
# Keep hanky in pocket
# Go back to Mississippi
# stop
# tell her you did not do it
# Listen closely my friends
# Never speak to me like that again
# Help in the arrest
# Drink a bourbon
# Load your weapon
# Please close the door
# Wake me up on the weekend
# Study hard for the math exam
# Turn right in 500 feet
# keep your friends close but your enemies closer
# Launch Google
# Drive to the roundabout and then turn left
# Stop that
# Collect nice books
# Work hard play hard
# Apply the glue thinly and leave it for ten minutes
# Get Lost
# Keep an eye on the time
# Leave the class
# Switch off the lights
# Pass the book please
# Please grill the sandwich
# Maintain silence
# Stay ahead
# Don't let the lights get turned on
# Let the dog out for play
# Reach for the sky
# Stop the track
# Slap the naughty boy
# You needn't give me a lift I will go by train
# Overhaul the passages
# do not left turn
# Remember the Sabbath day by keeping it holy
# Don't think about the future
# Stop feeding the lions
# Drink a port
# Fill in the blanks
# do not U turn
# Turn right in 200 feet
# Write an email to austin saying "You're the best"
# Crouch under the wall then slide under
# complete a u turn
# Let the river rock you like a cradle Climb to the treetops child if you're able Let your hands tie a knot across the table
# Come and touch the things you cannot feel And close your fingertips and fly where I can't hold you Let the sun rain fall and let the dewy clouds enfold you And maybe you can sing to me the words I just told you If all the things you feel ain't what they seem And don't mind me 'cause I ain't nothin' but a dream
# Have a safe journey
# Iron the shirt
# Call me tomorrow
# Listen before you speak
# Do not come home late
# Wear your gold necklace with that dress
# Remind me in 10 days to email Austin
# Swing hard johnny
# Find the document titled "test"
# Wake me up when suptember ends
# Summarize the news for me
# Smile for the camera
# Complete the photo shoot
# Launch Safari
# go
# Check if the laundry is dry
# Fold your laundry
# Let it occur then arrest them
# walk for the minimum
# clean the sidewalk
# Call your parents on sunday
# Discover the fall of the Roman Empire
# go back to Alabama
# May God bless you
# Cook the steak well done
# Please go and meet me at the middle of the dance floor after you perform your song
# Turn on the kitchen light
# talk to the hand
# Stop feeding the dog from the table
# Come around and see me some time
# Save our Souls
# Hit the ball
# Use the big red nipple to move around
# Complete all your work or else
# Please leave
# Fezzik tear his arms off
# Extract the information you can
# Get to bed on time
# Work fast
# Run fast
# Skip to the next track
# Find the document called "google"
# Sleep well
# Throw the ball
# Get vaccinated before the age of twelve months
# stir toegether flour baking soda and baking powder
# Talk to me about dan
# Take a taxi
# Write an email to john saying "This is a test email "
# Ask question if you have any
# Eat something
# Do your worst to me
# Drink lots of water
# Bring that to me
# Find the lost treasure
# go back to South Carolina go back to Georgia
# Give me a new TV
# Turn left at the intersection
# Do not honk
# Show me emails from Austin
# Do not make the naughty list
# Turn off the living room lights
# cross the pedestrian lane do not jay walk
# Complete mowing the lawn
# Crack the game
# sit in a semicircle
# Clap
# Put your hand into the bag
# break a leg
# Tell me about the weather
# Don't eat all the cookies
# Keep Calm and Carry On
# Honk if you like my driving
# stop yelling
# run
# Become who you need to be
# Please tidy your room
# let's eat
# run for your life
# go back to Louisiana
# Find documents from June 1st on
# pour me a glass of bourbon
# Play me a short clip
# Improve yourself or kiss yourself goodbye
# be there at five
# Roll the dice
# Go to bed early
# Close your eyes when you run away
# Leave me here alone to collect my things
# Eat your popcorn
# Lend me a dollar
# Please open the door would you
# Crack your iphone
# Don't trouble the children
# shut the front door
# Complete your work on sunday
# Clear this room by tomorrow morning
# Turn the record over
# Pack enough food for our adventure
# Ask for more work when you are done
# Do what I tell you to do
# Tell me whats in your wallet
# go back to the slums and ghettos of our northern cities knowing that somehow this situation can and will be changed
# Delete as much as you can
# Give me a Robert Heinlein quot
# Find the remote
# Don't feed the dog
# Have a good day
# Shut up Brain or I'll stab you with a Q tip
# tell me what you think
# please join me at the after party
# be kind to your neighbors
# Plant enough trees for the summer
# Come over here let me show you
# let's go out together
# Bring me my gun
# Complete the model validation
# move out of my way
# Please clap
# leave the package at the door
# Let us go to the college together Then you can come bo my dorm at night and we can have a good time
# oh behave
# Find documents from May 2017
# Order a new phone
# Please join me for dinner tonight
# Use oil in the pan
# Stop beating the cat
# Sit closer
# And so my fellow Americans ask not what your country can do for you ask what you can do for your country
# Choose wisely my friend
# Show me emails from Tom
# Suprise me
# Write an email to kim saying "This is not a test of the emergency broadcast system "
# stop crying over spilt milk
# say my name again
# do not stall
# Change the lightbulbs
# I need you to sit down now
# have a safe trip
# please be quite in the library
# make sure to pack warm clothes
# pass the salt
# Don't lose control
# Remove all the locks
# Become a better person
# Don't scare me like that
# let him cool down then ask about the incident
# Choose your battles
# Tell us the lies
# Give me the gun
# Tell the truth the whole truth and nothing but the truth
# Wash your shirts
# Paint a big wide smile
# Don't forget to feed the goldfish
# Let me go
# preheat the oven to 325
# Don't lose your way
# Don't forget to change your oil
# Bake a cake
# Come by after dark
# dont take things too seriously
# Launch Edge
# Dont talk
# please join us for breakfast
# Season the cast iron pan
# Do not enter
# Drive slowly
# listen to your teacher
# visit us in the hospital after the baby is born
# Delete all my notifications
# Change regularly
# Never give in Never give in Never never never never in nothing great or small large or petty never give in except to convictions of honor and good sense Never yield to force
# Never yield to the apparently overwhelming might of the enemy
# Turn on the lights so it's not dark
# Find me an expert in postgresql
# Taste the feeling
# Push me away I'll push you away
# Finish your JIRA tasks
# put that down now
# Write a blog post on Google Search
# Tell me a holidy limerick
# Have a good morning
# Come back with their head
# Raise your hand and turn around
# Do your chores
# Heat the house so you don't freeze
# Be careful about what you say
# Save the children
# Don't go anywhere
# Aristotle eleveate the matter
# Compose your atoms with Protons and neutrons
# Keep reading
# Run Forest Run
# Find me an expert in Ruby
# Find me an expert in Python
# Buy me some time
# Find a python developer
# Search for a scala developer
# Spy on all developers
# Launch IE6
# Blind everyone with your smile
# Cremate me when I die
# Wear your coat
# Work on your own
# Give me an easter egg
# Save the date
# Write a blog post on Sentence Type Classification
# Reboot the computer
# Reboot the router
# Reboot the laptop
# Come over after your shift
# Reboot the phone
# Turn off airplane mode
# Turn on the microphone
# Turn on airplane mode
# Turn on bluetooth
# Turn off bluetooth
# Create a new account when if you are hacked
# Turn on wifi
# Watch the fire burn out
# Turn off the wifi
# Shout loud
# Create value or leave
# Walk the line
# Breathe in the smoke
# Pick the nicest thing you can think of
# Walk back to Chicago
# Wake up in the morning
# Don't choke
# Say I love you
# Love me too
# roll over
# Jump on the count of three
# Save the dog if you can
# Bury your dog under the tree
# Add all the files tomorrow
# Don't run from a fight
# Add your comments to the document
# Edit the document adding our comments
# Beam us up
# Chop the carrots
# Join all the comments together
# Come into my home
# Get up stand up Stand up for your rights
# Get up stand up Don't give up the fight
# Join the war effort
# Mix flour and waters
# Break the eggs
# Cook the eggs
# Whisper when you tell me that
# Eat the eggs
# Check the current value before purchasing
# Skip what you can
# Save what you will
# Save all the data
# Swing the golf club harder next time
# Request data
# Request what you can
# Bury the bodies out back
# Skip annoying songs
# Select a winner then rank order the losers
# Raise your hand before you ask a question
# unmute
# unmute the device
# Do what you need to do to survive
# Set phasers to kill
# shut up
# louder
# softer
# speak to me with a british accent
# mute the chat
# mute
# Show me the money
# Fill up my gas tank before you come home
# Slice the steak into small pieces
# open the app
# Show me movie times
# show me the trailer
# ignore other commands
# Add the items to the shopping list so we don't forget next time we go
# increase the volume
# decrease the volume
# Buy a ThankPad it's amazing
# Show mercy to the captives
# Do not do what you shouldn't do
# Show me the TV guide
# set the timer for me
# Don't listen to a word I say
# Cancel the pizza timer
# Stop giving me the creeps
# Set a repeating alarm for weekdays at 9a m
# Please end the call
# Tell everyone goodnight I'll see everyone early tomorrow
# Help me help me
# Somebody help me
# Save me from Alexa
# Send message to Google from alexa
# End my call
# Please don't take the train tonight
# Call Jenny
# Order the bags of fertilzer
# Buy the bags of seed
# Fetch the hardest stick you can find
# Irrigate the fields for me
# Tell the truth
# Plow the lawn if you have time
# Sing a song if you know any
# Hum to the next song you hear
# Update my calendar with the last meeting discussion
# Please check the oven in five minutes
# Drive away without saying goodbye
# Tell me the truth
# Serve your guests some good food else they wont come back
# Remember to wash your sheets
# Open the door for me
# Open up the fridge
# Unlock my phone
# Come to my house when you can
# Come play super smash with me
# Look away
# Come in then Don't stand staring Close that door quick Hustle Don't scrape your feet on the floor Try to look intelligent Don't gape
# Take me back to Switzerland
# Take me to my bedroom
# Make me some Swiss fondue for dinner
# Bake me a cake now
# Come to my party
# Don't eat too much
# Go straight ahead then turn left
# Wake up now
# Don't touch me
# Don't panic
# Get the flag quickly
# Keep off the grass
# Park your car here
# Remove your shoes
# Post those letters
# Pay attention
# Take an asprin
# Don't let your dad know
# Don't let your mom know
# Let us go
# Let's do it
# Let it bleed
# Let it hurt
# Let it heal
# Let it go
# Read the text aloud
# Stand up when you are on the ground
# Drink a beer with me
# Come please
# Come on
# Don't eat so much
